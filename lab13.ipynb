# %% [markdown]
# # Wstęp
#
# Zadanie nr 13 wprowadza zagadnienie głębokich modeli uczenia ze wzmocnieniem (*Deep Reinforcement Learning*, **DRL**) - modeli, które uczone są przez interakcję z otoczeniem, obserwując konsekwencję działań oraz przyznawaną wartość nagrody.
#
# ## Cel ćwiczenia
#
# Celem ćwiczenia jest zapoznanie z:
# * koncepcją głębokiego uczenia ze wzmocnieniem,
# * podstawowymi podejściami w głębokim uczeniu ze wzmocnieniem,
# * przykładowymi środowiskami, wykorzystywanym w DRL,
# * jedną z podstawowych metod DRL opartą na funkcji wartości.

# %% [markdown]
# # Głębokie uczenie ze wzmocnieniem
#
# Podstawa reinforcement learning jest uczenie przez interakcje ̨: agent oddziałuje z otoczeniem i, obserwując konsekwencje jego działań, może uczyć się jak zmienić swoje zachowanie by zmaksymalizować wartość otrzymanej nagrody.
#
# ![image.png](data:image/png;base64,...)
#
# Zasada działania modelu uczenia ze wzmocnieniem jest następująca: autonomiczny agent, sterowany przez model, obserwuje **stan $s_t$ środowiska** w kroku czasowym $t$. Agent oddziałuje z otoczeniem podejmując **akcję $a_t$**, co powoduje przejście otoczenia i agenta do nowego stanu $s_{t+1}$. Przejście to odbywa się na podstawie **funkcji przejścia stanów $T(s_{t+1} | s_t, a_t)$** (równoważnej środowisku) - na podstawie aktualnego stanu i podjętej akcji. Zakładamy, że informacja o stanie jest wystarczająca dla agenta do podjęcia optymalnej akcji.
#
# Sekwencja akcji wybierana jest na podstawie nagrody, przyznawanej przez otoczenie agentowi. Każde przejście środowiska do nowego stanu powoduje nagrodzenie agenta **nagrodą $r_t$**, tj. wartością skalarną, określającą "poprawność" podjętej decyzji. Celem uczenia modelu DRL jest wyuczenie **strategii**, maksymalizującej łączną uzyskiwaną wartość nagrody (*zwrot*).
#
# Agent uczenia ze wzmocnieniem może składać się z następujących elementów (w zależności od stosowanego podejścia zawiera jeden lub więcej z nich):
# * **strategia** (ang. *policy*), tj. funkcja zachowywania się agenta; może być deterministyczna $a = \pi(s)$ lub stochastyczna $\pi(a|s)=p(a_t=a | s_t=s)$;
# * **funkcja wartości** (ang. *value function*), tj. funkcja służąca do predykcji przyszłej nagrody, używana do oceny stanów przy podejmowaniu akcji:
# $$V_{\pi}(s)=\mathbb{E}\left[r_{t+1}+\gamma r_{t+2}+\gamma^2 r_{t+3}+\dots | s_t=s\right],$$
# gdzie $\gamma\in[0, 1]$ to współczynnik dyskontowania, określający, w jakim stopniu faworyzowane są nagrody natychmiastowe;
# * **model**, służący do predykcji zmian w środowisku:
# $$\mathcal{P}_{ss'}^a = p(s_{t+1}=s | s_t=s, a_t=a),$$
# $$\mathcal{R}_s^a = \mathbb{E}[r_{t+1} | s_t=s, a_t=a],$$
# gdzie $\mathcal{P}$ przewiduje kolejny krok, a $\mathcal{R}$ wskazuje następną wartość nagrody.
#
# W zależności od elementów metody uczenia ze wzmocnieniem dzielimy na:
# * oparte na funkcji wartości (bez strategii) - trenujemy model aby poprawnie oceniał wartość nagrody za każdą z możliwych podejmowanych akcji,
# * oparte na strategii (bez funkcji wartości) - *policy gradient* - trenujemy model strategii, która bezpośrednio zwraca akcje, maksymalizujące wartość nagrody,
# * aktor-krytyk (wykorzystujące strategię oraz funkcję wartości) - połączenie powyższych (aktor to model strategii, kontrolujący zachowanie agenta, a krytyk to model funkcji wartości, oceniająca akcje podejmowane przez krytyka).
#
# Każda z tych metod może być też *model-free* (bez wykorzystania modelu środowiska) lub *model-based* (modelująca środowisko).
#
# W tym zadaniu skupimy się na **podejściu *model-free* opartym na funkcji wartości**.

# %% [markdown]
# ## Funkcje wartości
#
# Podejścia wykorzystujące funkcje wartości to metody oparte na estymowaniu wartości zwrotu (całkowitej nagrody). Wartość ta może być estymowana wyłącznie na podstawie aktualnego stanu - wówczas mówimy o **funkcji stan-wartość** $V^\pi(s) = \mathbb{E}[R | s, \pi]$, która ocenia wartość nagrody przy założeniu postępowania od danego stanu zgodnie ze strategią $\pi$. W idealnej sytuacji, optymalna strategia mogłaby być wybierana na podstawie akcji maksymalizujących oczekiwaną wartość nagrody; niestety jednak funkcja przejścia stanów $T(s_{t+1} | s_t, a_t)$ nie jest znana agentowi.
#
# Rozwiązaniem jest konstrukcja funkcji, która będzie estymowała wartość zwrot na podstawie stanu oraz podejmowanej akcji - **funkcja jakości** $Q^\pi(s, a) = \mathbb{E}[R | s, a, \pi]$ - tu oceniana jest wartość zwrotu po podjęciu danej akcji w danym stanie, przy postępowaniu dalej zgodnie ze strategią $\pi$. Wówczas, najlepsza strategia może być znaleziona przez zachłanny wybór akcji maksymalizującej wartość funkcji $Q$: $\arg\max_a Q^\pi(s, a)$, w ten sposób definiując aproksymację poszukiwanej funkcji wartości na podstawie maksymalizowania funkcji jakości:
#
# $$V^\pi(s) \approx \max_a Q^\pi(s, a).$$
#
# W takim podejściu skupiamy się na eksploatacji aktualnie wykrytego maksimum; często jednak chcielibyśmy również eksplorować rozwiązania alternatywne, na co pozwala strategia $\epsilon$-zachłanna (z prawdopodobieństwem $1-\epsilon$ wybieramy maksymalizującą akcję, a z prawdopodobieństwem $\epsilon$ - losową).
#
# Wartość funkcji jakości może być obliczona ze wzoru rekurencyjnego:
#
# $$Q^\pi(s_t, a_t) = \mathbb{E}_{s_{t+1}}\left[r_t + \gamma Q^\pi\left(s_{t+1}, \pi(s_{t+1})\right)\right],$$
#
# mówimy wówczas o podejściu *on-policy* - do estymacji całkowitej wartości zwrotu i wyboru akcji wykorzystuje się aktualną postać strategii (np. algorytm [SARSA](https://en.wikipedia.org/wiki/State–action–reward–state–action)). Alternatywnie, wybór akcji i estymacja wartości zwrotu może odbywać się poprzez zachłanny wybór akcji maksymalizującej wartość nagrody - mówimy wtedy o algorytmach *off-policy*:
#
# $$Q^\pi(s_t, a_t) = \mathbb{E}_{s_{t+1}}\left[r_t + \gamma \max_a Q^\pi\left(s_{t+1}, a_{t+1}\right)\right].$$
#
# Przykładem drugiej z grup metod jest [Q-learning](https://en.wikipedia.org/wiki/Q-learning). Polega on na budowaniu tabeli pamięci $Q[s, a]$, mającej przechowywać wartości funkcji jakości dla wszystkich możliwych kombinacji stanów $s$ i akcji $a$. Powstaje ona na skutek iteracyjnego próbkowania akcji z bieżącego stanu i zapisywania wartości zwrotu ($Y$), przy dalszym podejmowaniu akcji maksymalizujących wartość uzyskiwanej nagrody. Algorytm powtarzany jest iteracyjnie dla wszystkich możliwych akcji w danym stanie, po czym następuje przejście do kolejnego, niezbadanego stanu. W wytrenowanym modelu tabela ta wykorzystywana jest do wyboru akcji, maksymalizując wartość uzyskiwanej funkcji nagrody.

# %% [markdown]
# ## Deep Q-Learning (DQL)
#
# Algorytm Q-learning jest słabo skalowalny — w szczególności pod względem wymagań pamięciowych oraz złożoności obliczeniowej dla dużych przestrzeni stanów i akcji, dlatego też w DQN tabela pamięci została zastąpiona przez sieć głęboką (ang. *Deep Q-Network*), której zadaniem jest aproksymacja funkcji jakości $Q(s, a)$.
#
# Uczenie tej sieci odbywa się np. z użyciem funkcji celu - błędu średniokwadratowego między predykcją sieci a końcowymi wartościami zwrotu
#
# $$\mathcal{L} = \mathbb{E}\left[\left(r_t + \gamma \max_a Q^\pi\left(s_{t+1}, a_{t+1}\right) - Q^\pi\left(s_t, a_t\right)\right)^2\right].$$
#
# Można także użyć [Huber loss](https://en.wikipedia.org/wiki/Huber_loss).
#
# Algorytm uczenia tej sieci przedstawiony został poniżej:
#
# ```{tidy=FALSE, eval=FALSE}
# Get(s);                                         // pobierz stan początkowy
# for step <- 1, 2, ... till convergence do       // dla kolejnych kroków
#     Sample(a);                                  // wybierz akcję (epsilon-zachłannie)
#     Get(s');                                    // ustal nowy stan
#     if s' is terminal then                      // jeżeli nowy stan jest stanem końcowym
#         Y <- sum(r);                            // ustal wartość zwrotu
#         Sample(new s');                         // pobierz nowy stan początkowy
#     else:
#         Y <- r + gamma * Q_step(s', a')'        // aktualizuj estymację zwrotu
#     theta_k+1 <- theta - alpha * grad L(theta); // aktualizuj wagi zgodnie z funkcją celu
#     s <- s';                                    // weź nowy stan jako aktualny
# ```
#
# Wybrane ulepszenia:
#
# - **Zmienna wartość $\epsilon$**.
#     Zastosowanie stałej wartości $\epsilon$ w strategii $\epsilon$-zachłannej nie jest najlepszym rozwiązaniem. Zwykle wolelibyśmy, żeby w początkowym etapie model bardziej eksplorował przestrzeń (wyższy $\epsilon$), a w późniejszym etapie by eksploatował znalezione optimum (niższy $\epsilon$). Często stosuje się w tym celu funkcję wykładniczą.
#
# - ***Target network***.
#     Stosowane w celu poprawy stabilności trenowania. Polega ono na wykorzystaniu odrębnych instancji do działania w środowisku (*target network*) i odrębnej do trenowania w każdej iteracji (*policy network*). Początkowo, obie sieci są swoimi kopiami, a ich wagi są synchronizowane w trakcie trenowania w określonych interwałach. Algorytm trenowania modelu z *target network* prezentuje się następująco:
#
#     1. Wykonaj kopię modelu (*target network*)
#     1. Dla każdego kroku:
#         - wykonuj akcję w środowisku z użyciem *policy network* i zapisz czwórkę [stan, akcja, następny stan, nagroda] do utworzenia mini-batcha
#         - oblicz oczekiwane wartości funkcji Q używając *target network*
#         - oblicz loss i wykonaj propagację wsteczną w *policy network*
#     1. Cyklicznie synchronizuj wytrenowane wagi w *policy network* -> *target network*
#
# - ***Experience replay***.
#     Podobnie jak *target network* stosowane w celu poprawy stabilności trenowania. Polega ono na zapisywaniu czwórek: stan, akcja, kolejny stan i nagroda $(s_t, a_t, s_{t+1}, r_t)$ w pamięci o ograniczonej wielkości (*experience*). W celu uczenia modelu próbkujemy losowo mini-batch z *experience* i wykorzystujemy do trenowania. W ten sposób model uczony jest na danych niezależnych od siebie, poprawiając stabilność trenowania.
#
#     Wykorzystując *experience replay* algorytm trenowania będzie wyglądał następująco:
#
#     1. Zbuduj pamięć *experience* wykonując akcje niewytrenowanym modelem w środowisku i zapisując czwórki.
#     1. Dla każdego kroku uczenia:
#         - wykonaj akcję (1 lub więcej) w środowisku i zapisz w pamięci, usuwając najstarszy experience
#         - próbkuj batch z experience losowo i wykorzystaj do trenowania modelu (trenowanie odbywa się analogicznie jak wcześniej)

# %% [markdown]
# ### Uwaga ogólna
#
# Modele DRL, szczególnie w najbardziej "podstawowych" formach są niestabilne przy trenowaniu, dlatego też stosuje się wiele ulepszeń. Ponadto każdy błąd implementacyjny może mieć bardzo duży wpływ na zdolność modelu do wytrenowania, dlatego też w tych listach będziemy się opierać na gotowych implementacjach z biblioteki [**Stable-Baselines3**](https://stable-baselines.readthedocs.io). Opiera się ona na PyTorchu i zawiera sprawdzone i przetestowane implementacje wielu popularnych metod głębokiego uczenia ze wzmocnieniem. W tym laboratorium skupimy się na wspomnianej wcześniej metodzie Deep Q-Learning.

# %% [markdown]
# ## Środowisko
#
# W laboratorium będziemy wykorzystali bibliotekę [Gymnasium](https://gymnasium.farama.org/index.html) - zestaw narzędzi do budowy i porównywania algorytmów uczenia ze wzmocnieniem. Zawiera ona środowiska o różnym poziomie złożoności - zaczniemy od prostego środowiska - CartPole.
#
# ![image.png](data:image/png;base64,...)
# > oparte na: Barto, Sutton & Anderson *Neuronlike Adaptive Elements That Can Solve Difficult Learning Control Problem*, 1983
#
# Słupek zamocowany jest do wózka, który porusza się bez tarcia po ścieżce. Przestrzeń stanów jest czteroelementowa:
# * pozycja wózka,
# * szybkość wózka,
# * kąt nachylenia słupka,
# * szybkość obrotu słupka.
#
# Możemy kontrolować ruch wózka przykładając do niego siłę +1 lub -1. Celem jest zapobieganie przewróceniu słupka. Nagroda +1 przyznawana jest za każdy krok, kiedy słupek pozostaje pionowo. Epizod kończy się, gdy słupek odchylony jest o więcej niż 15 stopni od pionu, lub gry wózek odsunie się o ponad 2,4 jednostki od środka.

# %%
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gymnasium pyvirtualdisplay stable-baselines3[extra] > /dev/null 2>&1
# Out:
# The system cannot find the path specified.
# The system cannot find the path specified.

# %%
import os
import random

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import torch
from matplotlib import animation
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import plot_results, load_results
from stable_baselines3.dqn.policies import MlpPolicy

from IPython import display as ipythondisplay

SEED = 13
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

print("Środowisko zaimportowane pomyślnie!")
# Out:
# Środowisko zaimportowane pomyślnie!

# %% [markdown]
# Metoda Deep Q-Learning wraz z wymienionymi wcześniej ulepszeniami jest już zaimplementowana w bibliotece Stable-Baselines3. Najpierw sprawdźmy hiperparametry, jakie możemy podać do modelu:

# %%
help(DQN)
# Out:
# Help on class DQN in module stable_baselines3.dqn.dqn:
#
# class DQN(stable_baselines3.common.off_policy_algorithm.OffPolicyAlgorithm)
#  |  DQN(policy: str | type[stable_baselines3.dqn.policies.DQNPolicy], env: Union[gymnasium.core.Env, ForwardRef('VecEnv'), str], learning_rate: float | collections.abc.Callable[[float], float] = 0.0001, buffer_size: int = 1000000, learning_starts: int = 100, batch_size: int = 32, tau: float = 1.0, gamma: float = 0.99, train_freq: int | tuple[int, str] = 4, gradient_steps: int = 1, replay_buffer_class: type[stable_baselines3.common.buffers.ReplayBuffer] | None = None, replay_buffer_kwargs: dict[str, typing.Any] | None = None, optimize_memory_usage: bool = False, n_steps: int = 1, target_update_interval: int = 10000, exploration_fraction: float = 0.1, exploration_initial_eps: float = 1.0, exploration_final_eps: float = 0.05, max_grad_norm: float = 10, stats_window_size: int = 100, tensorboard_log: str | None = None, policy_kwargs: dict[str, typing.Any] | None = None, verbose: int = 0, seed: int | None = None, device: torch.device | str = 'auto', _init_setup_model: bool = True) -> None
#  |
#  |  Deep Q-Network (DQN)
#  |
#  |  Paper: https://arxiv.org/abs/1312.5602, https://www.nature.com/articles/nature14236
#  |  Default hyperparameters are taken from the Nature paper,
#  |  except for the optimizer and learning rate that were taken from Stable Baselines defaults.
#  |
#  |  :param policy: The policy model to use (MlpPolicy, CnnPolicy, ...)
#  |  :param env: The environment to learn from (if registered in Gym, can be str)
#  |  :param learning_rate: The learning rate, it can be a function
#  |      of the current progress remaining (from 1 to 0)
#  |  :param buffer_size: size of the replay buffer
#  |  :param learning_starts: how many steps of the model to collect transitions for before learning starts
#  |  :param batch_size: Minibatch size for each gradient update
#  |  :param tau: the soft update coefficient ("Polyak update", between 0 and 1) default 1 for hard update
#  |  :param gamma: the discount factor
#  |  :param train_freq: Update the model every ``train_freq`` steps. Alternatively pass a tuple of frequency and unit
#  |      like ``(5, "step")`` or ``(2, "episode")``.
#  |  :param gradient_steps: How many gradient steps to do after each rollout (see ``train_freq``)
#  |      Set to ``-1`` means to do as many gradient steps as steps done in the environment
#  |      during the rollout.
#  |  :param replay_buffer_class: Replay buffer class to use (for instance ``HerReplayBuffer``).
#  |      If ``None``, it will be automatically selected.
#  |  :param replay_buffer_kwargs: Keyword arguments to pass to the replay buffer on creation.
#  |  :param optimize_memory_usage: Enable a memory efficient variant of the replay buffer
#  |      at a cost of more complexity.
#  |      See https://github.com/DLR-RM/stable-baselines3/issues/37#issuecomment-637501195
#  |  :param n_steps: When n_step > 1, uses n-step return (with the NStepReplayBuffer) when updating the Q-value network.
#  |  :param target_update_interval: update the target network every ``target_update_interval``
#  |      environment steps.
#  |  :param exploration_fraction: fraction of entire training period over which the exploration rate is reduced
#  |  :param exploration_initial_eps: initial value of random action probability
#  |  :param exploration_final_eps: final value of random action probability
#  |  :param max_grad_norm: The maximum value for the gradient clipping
#  |  :param stats_window_size: Window size for the rollout logging, specifying the number of episodes to average
#  |      the reported success rate, mean episode length, and mean reward over
#  |  :param tensorboard_log: the log location for tensorboard (if None, no logging)
#  |  :param policy_kwargs: additional arguments to be passed to the policy on creation. See :ref:`dqn_policies`
#  |  :param verbose: Verbosity level: 0 for no output, 1 for info messages (such as device or wrappers used), 2 for
#  |      debug messages
#  |  :param seed: Seed for the pseudo random generators
#  |  :param device: Device (cpu, cuda, ...) on which the code should be run.
#  |      Setting it to auto, the code will be run on the GPU if possible.
#  |  :param _init_setup_model: Whether or not to build the network at the creation of the instance
#  |
#  |  Method resolution order:
#  |      DQN
#  |      stable_baselines3.common.off_policy_algorithm.OffPolicyAlgorithm
#  |      stable_baselines3.common.base_class.BaseAlgorithm
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, policy: str | type[stable_baselines3.dqn.policies.DQNPolicy], env: Union[gymnasium.core.Env, ForwardRef('VecEnv'), str], learning_rate: float | collections.abc.Callable[[float], float] = 0.0001, buffer_size: int = 1000000, learning_starts: int = 100, batch_size: int = 32, tau: float = 1.0, gamma: float = 0.99, train_freq: int | tuple[int, str] = 4, gradient_steps: int = 1, replay_buffer_class: type[stable_baselines3.common.buffers.ReplayBuffer] | None = None, replay_buffer_kwargs: dict[str, typing.Any] | None = None, optimize_memory_usage: bool = False, n_steps: int = 1, target_update_interval: int = 10000, exploration_fraction: float = 0.1, exploration_initial_eps: float = 1.0, exploration_final_eps: float = 0.05, max_grad_norm: float = 10, stats_window_size: int = 100, tensorboard_log: str | None = None, policy_kwargs: dict[str, typing.Any] | None = None, verbose: int = 0, seed: int | None = None, device: torch.device | str = 'auto', _init_setup_model: bool = True) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  learn(self: ~SelfDQN, total_timesteps: int, callback: Union[NoneType, collections.abc.Callable, list['BaseCallback'], ForwardRef('BaseCallback')] = None, log_interval: int = 4, tb_log_name: str = 'DQN', reset_num_timesteps: bool = True, progress_bar: bool = False) -> ~SelfDQN
#  |      Return a trained model.
#  |
#  |      :param total_timesteps: The total number of samples (env steps) to train on
#  |          Note: it is a lower bound, see `issue #1150 <https://github.com/DLR-RM/stable-baselines3/issues/1150>`_
#  |      :param callback: callback(s) called at every step with state of the algorithm.
#  |      :param log_interval: for on-policy algos (e.g., PPO, A2C, ...) this is the number of
#  |          training iterations (i.e., log_interval * n_steps * n_envs timesteps) before logging;
#  |          for off-policy algos (e.g., TD3, SAC, ...) this is the number of episodes before
#  |          logging.
#  |      :param tb_log_name: the name of the run for TensorBoard logging
#  |      :param reset_num_timesteps: whether or not to reset the current timestep number (used in logging)
#  |      :param progress_bar: Display a progress bar using tqdm and rich.
#  |      :return: the trained model
#  |
#  |  predict(self, observation: numpy.ndarray | dict[str, numpy.ndarray], state: tuple[numpy.ndarray, ...] | None = None, episode_start: numpy.ndarray | None = None, deterministic: bool = False) -> tuple[numpy.ndarray, tuple[numpy.ndarray, ...] | None]
#  |      Overrides the base_class predict function to include epsilon-greedy exploration.
#  |
#  |      :param observation: the input observation
#  |      :param state: The last states (can be None, used in recurrent policies)
#  |      :param episode_start: The last masks (can be None, used in recurrent policies)
#  |      :param deterministic: Whether or not to return deterministic actions.
#  |      :return: the model's action and the next state
#  |          (used in recurrent policies)
#  |
#  |  train(self, gradient_steps: int, batch_size: int = 100) -> None
#  |      Sample the replay buffer and do the updates
#  |      (gradient descent and update target networks)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  __annotations__ = {'exploration_schedule': collections.abc.Callable[[f...
#  |
#  |  policy_aliases = {'CnnPolicy': <class 'stable_baselines3.dqn.policies....
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from stable_baselines3.common.off_policy_algorithm.OffPolicyAlgorithm:
#  |
#  |  collect_rollouts(self, env: stable_baselines3.common.vec_env.base_vec_env.VecEnv, callback: stable_baselines3.common.callbacks.BaseCallback, train_freq: stable_baselines3.common.type_aliases.TrainFreq, replay_buffer: stable_baselines3.common.buffers.ReplayBuffer, action_noise: stable_baselines3.common.noise.ActionNoise | None = None, learning_starts: int = 0, log_interval: int | None = None) -> stable_baselines3.common.type_aliases.RolloutReturn
#  |      Collect experiences and store them into a ``ReplayBuffer``.
#  |
#  |      :param env: The training environment
#  |      :param callback: Callback that will be called at each step
#  |          (and at the beginning and end of the rollout)
#  |      :param train_freq: How much experience to collect
#  |          by doing rollouts of current policy.
#  |          Either ``TrainFreq(<n>, TrainFrequencyUnit.STEP)``
#  |          or ``TrainFreq(<n>, TrainFrequencyUnit.EPISODE)``
#  |          with ``<n>`` being an integer greater than 0.
#  |      :param action_noise: Action noise that will be used for exploration
#  |          Required for deterministic policy (e.g. TD3). This can also be used
#  |          in addition to the stochastic policy for SAC.
#  |      :param learning_starts: Number of steps before learning for the warm-up phase.
#  |      :param replay_buffer:
#  |      :param log_interval: Log data every ``log_interval`` episodes
#  |      :return:
#  |
#  |  dump_logs(self) -> None
#  |      Write log data.
#  |
#  |  load_replay_buffer(self, path: str | pathlib.Path | io.BufferedIOBase, truncate_last_traj: bool = True) -> None
#  |      Load a replay buffer from a pickle file.
#  |
#  |      :param path: Path to the pickled replay buffer.
#  |      :param truncate_last_traj: When using ``HerReplayBuffer`` with online sampling:
#  |          If set to ``True``, we assume that the last trajectory in the replay buffer was finished
#  |          (and truncate it).
#  |          If set to ``False``, we assume that we continue the same trajectory (same episode).
#  |
#  |  save_replay_buffer(self, path: str | pathlib.Path | io.BufferedIOBase) -> None
#  |      Save the replay buffer as a pickle file.
#  |
#  |      :param path: Path to the file where the replay buffer should be saved.
#  |          if path is a str or pathlib.Path, the path is automatically created if necessary.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from stable_baselines3.common.base_class.BaseAlgorithm:
#  |
#  |  get_env(self) -> stable_baselines3.common.vec_env.base_vec_env.VecEnv | None
#  |      Returns the current environment (can be None if not defined).
#  |
#  |      :return: The current environment
#  |
#  |  get_parameters(self) -> dict[str, dict]
#  |      Return the parameters of the agent. This includes parameters from different networks, e.g.
#  |      critics (value functions) and policies (pi functions).
#  |
#  |      :return: Mapping of from names of the objects to PyTorch state-dicts.
#  |
#  |  get_vec_normalize_env(self) -> stable_baselines3.common.vec_env.vec_normalize.VecNormalize | None
#  |      Return the ``VecNormalize`` wrapper of the training env
#  |      if it exists.
#  |
#  |      :return: The ``VecNormalize`` env.
#  |
#  |  save(self, path: str | pathlib.Path | io.BufferedIOBase, exclude: collections.abc.Iterable[str] | None = None, include: collections.abc.Iterable[str] | None = None) -> None
#  |      Save all the attributes of the object and the model parameters in a zip-file.
#  |
#  |      :param path: path to the file where the rl agent should be saved
#  |      :param exclude: name of parameters that should be excluded in addition to the default ones
#  |      :param include: name of parameters that might be excluded but should be included anyway
#  |
#  |  set_env(self, env: Union[gymnasium.core.Env, ForwardRef('VecEnv')], force_reset: bool = True) -> None
#  |      Checks the validity of the environment, and if it is coherent, set it as the current environment.
#  |      Furthermore wrap any non vectorized env into a vectorized
#  |      checked parameters:
#  |      - observation_space
#  |      - action_space
#  |
#  |      :param env: The environment for learning a policy
#  |      :param force_reset: Force call to ``reset()`` before training
#  |          to avoid unexpected behavior.
#  |          See issue https://github.com/DLR-RM/stable-baselines3/issues/597
#  |
#  |  set_logger(self, logger: stable_baselines3.common.logger.Logger) -> None
#  |      Setter for for logger object.
#  |
#  |      .. warning::
#  |
#  |        When passing a custom logger object,
#  |        this will overwrite ``tensorboard_log`` and ``verbose`` settings
#  |        passed to the constructor.
#  |
#  |  set_parameters(self, load_path_or_dict: str | dict[str, torch.Tensor], exact_match: bool = True, device: torch.device | str = 'auto') -> None
#  |      Load parameters from a given zip-file or a nested dictionary containing parameters for
#  |      different modules (see ``get_parameters``).
#  |
#  |      :param load_path_or_iter: Location of the saved data (path or file-like, see ``save``), or a nested
#  |          dictionary containing nn.Module parameters used by the policy. The dictionary maps
#  |          object names to a state-dictionary returned by ``torch.nn.Module.state_dict()``.
#  |      :param exact_match: If True, the given parameters should include parameters for each
#  |          module and each of their parameters, otherwise raises an Exception. If set to False, this
#  |          can be used to update only specific parameters.
#  |      :param device: Device on which the code should run.
#  |
#  |  set_random_seed(self, seed: int | None = None) -> None
#  |      Set the seed of the pseudo-random generators
#  |      (python, numpy, pytorch, gym, action_space)
#  |
#  |      :param seed:
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from stable_baselines3.common.base_class.BaseAlgorithm:
#  |
#  |  load(path: str | pathlib.Path | io.BufferedIOBase, env: Union[gymnasium.core.Env, ForwardRef('VecEnv'), NoneType] = None, device: torch.device | str = 'auto', custom_objects: dict[str, typing.Any] | None = None, print_system_info: bool = False, force_reset: bool = True, **kwargs) -> ~SelfBaseAlgorithm
#  |      Load the model from a zip-file.
#  |      Warning: ``load`` re-creates the model from scratch, it does not update it in-place!
#  |      For an in-place load use ``set_parameters`` instead.
#  |
#  |      :param path: path to the file (or a file-like) where to
#  |          load the agent from
#  |      :param env: the new environment to run the loaded model on
#  |          (can be None if you only need prediction from a trained model) has priority over any saved environment
#  |      :param device: Device on which the code should run.
#  |      :param custom_objects: Dictionary of objects to replace
#  |          upon loading. If a variable is present in this dictionary as a
#  |          key, it will not be deserialized and the corresponding item
#  |          will be used instead. Similar to custom_objects in
#  |          ``keras.models.load_model``. Useful when you have an object in
#  |          file that can not be deserialized.
#  |      :param print_system_info: Whether to print system info from the saved model
#  |          and the current system info (useful to debug loading issues)
#  |      :param force_reset: Force call to ``reset()`` before training
#  |          to avoid unexpected behavior.
#  |          See https://github.com/DLR-RM/stable-baselines3/issues/597
#  |      :param kwargs: extra arguments to change the model when loading
#  |      :return: new model instance with loaded parameters
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from stable_baselines3.common.base_class.BaseAlgorithm:
#  |
#  |  logger
#  |      Getter for the logger object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from stable_baselines3.common.base_class.BaseAlgorithm:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %% [markdown]
# Kluczowym argumentem podawanym do modelu jest `policy`, czyli model strategii wykorzystywany w modelu. W Stable-Baselines3 każda metoda DRL posiada własny zestaw strategii - w przypadku DQN dostępne są trzy wersje (moduł `stable_baselines3.dqn.policies`:
# - `MlpPolicy` - w pełni połączona
# - `CnnPolicy` - z warstwami konwolucyjnymi
# - `MultiInputPolicy` - dla środowisk, które umożliwiają obserwacje w formie obrazów jak i wartości.
#
# W tym przykładzie będziemy wykorzystywać `MlpPolicy`, ponieważ środowisko nie zwraca obserwacji w formie obrazów. Sprawdźmy zatem, jakie argumenty ona przyjmuje (mogą one być przekazywane przez argument modelu `policy_kwargs`).

# %%
help(MlpPolicy)
# Out:
# Help on class DQNPolicy in module stable_baselines3.dqn.policies:
#
# class DQNPolicy(stable_baselines3.common.policies.BasePolicy)
#  |  DQNPolicy(observation_space: gymnasium.spaces.space.Space, action_space: gymnasium.spaces.discrete.Discrete, lr_schedule: collections.abc.Callable[[float], float], net_arch: list[int] | None = None, activation_fn: type[torch.nn.modules.module.Module] = <class 'torch.nn.modules.activation.ReLU'>, features_extractor_class: type[stable_baselines3.common.torch_layers.BaseFeaturesExtractor] = <class 'stable_baselines3.common.torch_layers.FlattenExtractor'>, features_extractor_kwargs: dict[str, typing.Any] | None = None, normalize_images: bool = True, optimizer_class: type[torch.optim.optimizer.Optimizer] = <class 'torch.optim.adam.Adam'>, optimizer_kwargs: dict[str, typing.Any] | None = None) -> None
#  |
#  |  Policy class with Q-Value Net and target net for DQN
#  |
#  |  :param observation_space: Observation space
#  |  :param action_space: Action space
#  |  :param lr_schedule: Learning rate schedule (could be constant)
#  |  :param net_arch: The specification of the policy and value networks.
#  |  :param activation_fn: Activation function
#  |  :param features_extractor_class: Features extractor to use.
#  |  :param features_extractor_kwargs: Keyword arguments
#  |      to pass to the features extractor.
#  |  :param normalize_images: Whether to normalize images or not,
#  |       dividing by 255.0 (True by default)
#  |  :param optimizer_class: The optimizer to use,
#  |      ``th.optim.Adam`` by default
#  |  :param optimizer_kwargs: Additional keyword arguments,
#  |      excluding the learning rate, to pass to the optimizer
#  |
#  |  Method resolution order:
#  |      DQNPolicy
#  |      stable_baselines3.common.policies.BasePolicy
#  |      stable_baselines3.common.policies.BaseModel
#  |      torch.nn.modules.module.Module
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, observation_space: gymnasium.spaces.space.Space, action_space: gymnasium.spaces.discrete.Discrete, lr_schedule: collections.abc.Callable[[float], float], net_arch: list[int] | None = None, activation_fn: type[torch.nn.modules.module.Module] = <class 'torch.nn.modules.activation.ReLU'>, features_extractor_class: type[stable_baselines3.common.torch_layers.BaseFeaturesExtractor] = <class 'stable_baselines3.common.torch_layers.FlattenExtractor'>, features_extractor_kwargs: dict[str, typing.Any] | None = None, normalize_images: bool = True, optimizer_class: type[torch.optim.optimizer.Optimizer] = <class 'torch.optim.adam.Adam'>, optimizer_kwargs: dict[str, typing.Any] | None = None) -> None
#  |      Initialize internal Module state, shared by both nn.Module and ScriptModule.
#  |
#  |  forward(self, obs: Union[torch.Tensor, dict[str, torch.Tensor]], deterministic: bool = True) -> torch.Tensor
#  |      Define the computation performed at every call.
#  |
#  |      Should be overridden by all subclasses.
#  |
#  |      .. note::
#  |          Although the recipe for forward pass needs to be defined within
#  |          this function, one should call the :class:`Module` instance afterwards
#  |          instead of this since the former takes care of running the
#  |          registered hooks while the latter silently ignores them.
#  |
#  |  make_q_net(self) -> stable_baselines3.dqn.policies.QNetwork
#  |
#  |  set_training_mode(self, mode: bool) -> None
#  |      Put the policy in either training or evaluation mode.
#  |
#  |      This affects certain modules, such as batch normalisation and dropout.
#  |
#  |      :param mode: if true, set to training mode, else set to evaluation mode
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  __annotations__ = {'q_net': <class 'stable_baselines3.dqn.policies.QNe...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from stable_baselines3.common.policies.BasePolicy:
#  |
#  |  predict(self, observation: numpy.ndarray | dict[str, numpy.ndarray], state: tuple[numpy.ndarray, ...] | None = None, episode_start: numpy.ndarray | None = None, deterministic: bool = False) -> tuple[numpy.ndarray, tuple[numpy.ndarray, ...] | None]
#  |      Get the policy action from an observation (and optional hidden state).
#  |      Includes sugar-coating to handle different observations (e.g. normalizing images).
#  |
#  |      :param observation: the input observation
#  |      :param state: The last hidden states (can be None, used in recurrent policies)
#  |      :param episode_start: The last masks (can be None, used in recurrent policies)
#  |          this correspond to beginning of episodes,
#  |          where the hidden states of the RNN must be reset.
#  |      :param deterministic: Whether or not to return deterministic actions.
#  |      :return: the model's action and the next hidden state
#  |          (used in recurrent policies)
#  |
#  |  scale_action(self, action: numpy.ndarray) -> numpy.ndarray
#  |      Rescale the action from [low, high] to [-1, 1]
#  |      (no need for symmetric action space)
#  |
#  |      :param action: Action to scale
#  |      :return: Scaled action
#  |
#  |  unscale_action(self, scaled_action: numpy.ndarray) -> numpy.ndarray
#  |      Rescale the action from [-1, 1] to [low, high]
#  |      (no need for symmetric action space)
#  |
#  |      :param scaled_action: Action to un-scale
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from stable_baselines3.common.policies.BasePolicy:
#  |
#  |  init_weights(module: torch.nn.modules.module.Module, gain: float = 1) -> None
#  |      Orthogonal initialization (used in PPO and A2C)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from stable_baselines3.common.policies.BasePolicy:
#  |
#  |  squash_output
#  |      (bool) Getter for squash_output.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from stable_baselines3.common.policies.BaseModel:
#  |
#  |  extract_features(self, obs: Union[torch.Tensor, dict[str, torch.Tensor]], features_extractor: stable_baselines3.common.torch_layers.BaseFeaturesExtractor) -> torch.Tensor
#  |      Preprocess the observation if needed and extract features.
#  |
#  |      :param obs: Observation
#  |      :param features_extractor: The features extractor to use.
#  |      :return: The extracted features
#  |
#  |  is_vectorized_observation(self, observation: numpy.ndarray | dict[str, numpy.ndarray]) -> bool
#  |      Check whether or not the observation is vectorized,
#  |      apply transposition to image (so that they are channel-first) if needed.
#  |      This is used in DQN when sampling random action (epsilon-greedy policy)
#  |
#  |      :param observation: the input observation to check
#  |      :return: whether the given observation is vectorized or not
#  |
#  |  load_from_vector(self, vector: numpy.ndarray) -> None
#  |      Load parameters from a 1D vector.
#  |
#  |      :param vector:
#  |
#  |  make_features_extractor(self) -> stable_baselines3.common.torch_layers.BaseFeaturesExtractor
#  |      Helper method to create a features extractor.
#  |
#  |  obs_to_tensor(self, observation: numpy.ndarray | dict[str, numpy.ndarray]) -> tuple[typing.Union[torch.Tensor, dict[str, torch.Tensor]], bool]
#  |      Convert an input observation to a PyTorch tensor that can be fed to a model.
#  |      Includes sugar-coating to handle different observations (e.g. normalizing images).
#  |
#  |      :param observation: the input observation
#  |      :return: The observation as PyTorch tensor
#  |          and whether the observation is vectorized or not
#  |
#  |  parameters_to_vector(self) -> numpy.ndarray
#  |      Convert the parameters to a 1D vector.
#  |
#  |      :return:
#  |
#  |  save(self, path: str) -> None
#  |      Save model to a given location.
#  |
#  |      :param path:
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from stable_baselines3.common.policies.BaseModel:
#  |
#  |  load(path: str, device: torch.device | str = 'auto') -> ~SelfBaseModel
#  |      Load model from path.
#  |
#  |      :param path:
#  |      :param device: Device on which the policy should be loaded.
#  |      :return:
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from stable_baselines3.common.policies.BaseModel:
#  |
#  |  device
#  |      Infer which device this policy lives on by inspecting its parameters.
#  |      If it has no parameters, the 'cpu' device is used as a fallback.
#  |
#  |      :return:
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from torch.nn.modules.module.Module:
#  |
#  |  __call__ = _wrapped_call_impl(self, *args, **kwargs)
#  |
#  |  __delattr__(self, name)
#  |      Implement delattr(self, name).
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __getattr__(self, name: str) -> Any
#  |      # On the return type:
#  |      # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#  |      # This is done for better interop with various type checkers for the end users.
#  |      # Having a stricter return type doesn't play nicely with `register_buffer()` and forces
#  |      # people to excessively use type-ignores, asserts, casts, etc.
#  |      # See full discussion on the problems with returning `Union` here
#  |      # https://github.com/microsoft/pyright/issues/4213
#  |
#  |  __getstate__(self)
#  |      Helper for pickle.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name: str, value: Union[torch.Tensor, ForwardRef('Module')]) -> None
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(self, state)
#  |
#  |  add_module(self, name: str, module: Optional[ForwardRef('Module')]) -> None
#  |      Add a child module to the current module.
#  |
#  |      The module can be accessed as an attribute using the given name.
#  |
#  |      Args:
#  |          name (str): name of the child module. The child module can be
#  |              accessed from this module using the given name
#  |          module (Module): child module to be added to the module.
#  |
#  |  apply(self: ~T, fn: Callable[[ForwardRef('Module')], NoneType]) -> ~T
#  |      Apply ``fn`` recursively to every submodule (as returned by ``.children()``) as well as self.
#  |
#  |      Typical use includes initializing the parameters of a model
#  |      (see also :ref:`nn-init-doc`).
#  |
#  |      Args:
#  |          fn (:class:`Module` -> None): function to be applied to each submodule
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |      Example::
#  |
#  |          >>> @torch.no_grad()
#  |          >>> def init_weights(m):
#  |          >>>     print(m)
#  |          >>>     if type(m) == nn.Linear:
#  |          >>>         m.weight.fill_(1.0)
#  |          >>>         print(m.weight)
#  |          >>> net = nn.Sequential(nn.Linear(2, 2), nn.Linear(2, 2))
#  |          >>> net.apply(init_weights)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          Parameter containing:
#  |          tensor([[1., 1.],
#  |                  [1., 1.]], requires_grad=True)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          Parameter containing:
#  |          tensor([[1., 1.],
#  |                  [1., 1.]], requires_grad=True)
#  |          Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          )
#  |
#  |  bfloat16(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``bfloat16`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  buffers(self, recurse: bool = True) -> Iterator[torch.Tensor]
#  |      Return an iterator over module buffers.
#  |
#  |      Args:
#  |          recurse (bool): if True, then yields buffers of this module
#  |              and all submodules. Otherwise, yields only buffers that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          torch.Tensor: module buffer
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for buf in model.buffers():
#  |          >>>     print(type(buf), buf.size())
#  |          <class 'torch.Tensor'> (20L,)
#  |          <class 'torch.Tensor'> (20L, 1L, 5L, 5L)
#  |
#  |  children(self) -> Iterator[ForwardRef('Module')]
#  |      Return an iterator over immediate children modules.
#  |
#  |      Yields:
#  |          Module: a child module
#  |
#  |  compile(self, *args, **kwargs)
#  |      Compile this Module's forward using :func:`torch.compile`.
#  |
#  |      This Module's `__call__` method is compiled and all arguments are passed as-is
#  |      to :func:`torch.compile`.
#  |
#  |      See :func:`torch.compile` for details on the arguments for this function.
#  |
#  |  cpu(self: ~T) -> ~T
#  |      Move all model parameters and buffers to the CPU.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  cuda(self: ~T, device: Union[int, torch.device, NoneType] = None) -> ~T
#  |      Move all model parameters and buffers to the GPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on GPU while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Args:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  double(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``double`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  eval(self: ~T) -> ~T
#  |      Set the module in evaluation mode.
#  |
#  |      This has any effect only on certain modules. See documentations of
#  |      particular modules for details of their behaviors in training/evaluation
#  |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#  |      etc.
#  |
#  |      This is equivalent with :meth:`self.train(False) <torch.nn.Module.train>`.
#  |
#  |      See :ref:`locally-disable-grad-doc` for a comparison between
#  |      `.eval()` and several similar mechanisms that may be confused with it.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  extra_repr(self) -> str
#  |      Set the extra representation of the module.
#  |
#  |      To print customized extra information, you should re-implement
#  |      this method in your own modules. Both single-line and multi-line
#  |      strings are acceptable.
#  |
#  |  float(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``float`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  get_buffer(self, target: str) -> 'Tensor'
#  |      Return the buffer given by ``target`` if it exists, otherwise throw an error.
#  |
#  |      See the docstring for ``get_submodule`` for a more detailed
#  |      explanation of this method's functionality as well as how to
#  |      correctly specify ``target``.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the buffer
#  |              to look for. (See ``get_submodule`` for how to specify a
#  |              fully-qualified string.)
#  |
#  |      Returns:
#  |          torch.Tensor: The buffer referenced by ``target``
#  |
#  |      Raises:
#  |          AttributeError: If the target string references an invalid
#  |              path or resolves to something that is not a
#  |              buffer
#  |
#  |  get_extra_state(self) -> Any
#  |      Return any extra state to include in the module's state_dict.
#  |
#  |      Implement this and a corresponding :func:`set_extra_state` for your module
#  |      if you need to store extra state. This function is called when building the
#  |      module's `state_dict()`.
#  |
#  |      Note that extra state should be picklable to ensure working serialization
#  |      of the state_dict. We only provide provide backwards compatibility guarantees
#  |      for serializing Tensors; other objects may break backwards compatibility if
#  |      their serialized pickled form changes.
#  |
#  |      Returns:
#  |          object: Any extra state to store in the module's state_dict
#  |
#  |  get_parameter(self, target: str) -> 'Parameter'
#  |      Return the parameter given by ``target`` if it exists, otherwise throw an error.
#  |
#  |      See the docstring for ``get_submodule`` for a more detailed
#  |      explanation of this method's functionality as well as how to
#  |      correctly specify ``target``.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the Parameter
#  |              to look for. (See ``get_submodule`` for how to specify a
#  |              fully-qualified string.)
#  |
#  |      Returns:
#  |          torch.nn.Parameter: The Parameter referenced by ``target``
#  |
#  |      Raises:
#  |          AttributeError: If the target string references an invalid
#  |              path or resolves to something that is not an
#  |              ``nn.Parameter``
#  |
#  |  get_submodule(self, target: str) -> 'Module'
#  |      Return the submodule given by ``target`` if it exists, otherwise throw an error.
#  |
#  |      For example, let's say you have an ``nn.Module`` ``A`` that
#  |      looks like this:
#  |
#  |      .. code-block:: text
#  |
#  |          A(
#  |              (net_b): Module(
#  |                  (net_c): Module(
#  |                      (conv): Conv2d(16, 33, kernel_size=(3, 3), stride=(2, 2))
#  |                  )
#  |                  (linear): Linear(in_features=100, out_features=200, bias=True)
#  |              )
#  |          )
#  |
#  |      (The diagram shows an ``nn.Module`` ``A``. ``A`` has a nested
#  |      submodule ``net_b``, which itself has two submodules ``net_c``
#  |      and ``linear``. ``net_c`` then has a submodule ``conv``.)
#  |
#  |      To check whether or not we have the ``linear`` submodule, we
#  |      would call ``get_submodule("net_b.linear")``. To check whether
#  |      we have the ``conv`` submodule, we would call
#  |      ``get_submodule("net_b.net_c.conv")``.
#  |
#  |      The runtime of ``get_submodule`` is bounded by the degree
#  |      of module nesting in ``target``. A query against
#  |      ``named_modules`` achieves the same result, but it is O(N) in
#  |      the number of transitive modules. So, for a simple check to see
#  |      if some submodule exists, ``get_submodule`` should always be
#  |      used.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the submodule
#  |              to look for. (See above example for how to specify a
#  |              fully-qualified string.)
#  |
#  |      Returns:
#  |          torch.nn.Module: The submodule referenced by ``target``
#  |
#  |      Raises:
#  |          AttributeError: If the target string references an invalid
#  |              path or resolves to something that is not an
#  |              ``nn.Module``
#  |
#  |  half(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``half`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  ipu(self: ~T, device: Union[int, torch.device, NoneType] = None) -> ~T
#  |      Move all model parameters and buffers to the IPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on IPU while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Arguments:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  load_state_dict(self, state_dict: Mapping[str, Any], strict: bool = True, assign: bool = False)
#  |      Copy parameters and buffers from :attr:`state_dict` into this module and its descendants.
#  |
#  |      If :attr:`strict` is ``True``, then
#  |      the keys of :attr:`state_dict` must exactly match the keys returned
#  |      by this module's :meth:`~torch.nn.Module.state_dict` function.
#  |
#  |      .. warning::
#  |          If :attr:`assign` is ``True`` the optimizer must be created after
#  |          the call to :attr:`load_state_dict` unless
#  |          :func:`~torch.__future__.get_swap_module_params_on_conversion` is ``True``.
#  |
#  |      Args:
#  |          state_dict (dict): a dict containing parameters and
#  |              persistent buffers.
#  |          strict (bool, optional): whether to strictly enforce that the keys
#  |              in :attr:`state_dict` match the keys returned by this module's
#  |              :meth:`~torch.nn.Module.state_dict` function. Default: ``True``
#  |          assign (bool, optional): When ``False``, the properties of the tensors
#  |              in the current module are preserved while when ``True``, the
#  |              properties of the Tensors in the state dict are preserved. The only
#  |              exception is the ``requires_grad`` field of :class:`~torch.nn.Parameter`s
#  |              for which the value from the module is preserved.
#  |              Default: ``False``
#  |
#  |      Returns:
#  |          ``NamedTuple`` with ``missing_keys`` and ``unexpected_keys`` fields:
#  |              * **missing_keys** is a list of str containing any keys that are expected
#  |                  by this module but missing from the provided ``state_dict``.
#  |              * **unexpected_keys** is a list of str containing the keys that are not
#  |                  expected by this module but present in the provided ``state_dict``.
#  |
#  |      Note:
#  |          If a parameter or buffer is registered as ``None`` and its corresponding key
#  |          exists in :attr:`state_dict`, :meth:`load_state_dict` will raise a
#  |          ``RuntimeError``.
#  |
#  |  modules(self) -> Iterator[ForwardRef('Module')]
#  |      Return an iterator over all modules in the network.
#  |
#  |      Yields:
#  |          Module: a module in the network
#  |
#  |      Note:
#  |          Duplicate modules are returned only once. In the following
#  |          example, ``l`` will be returned only once.
#  |
#  |      Example::
#  |
#  |          >>> l = nn.Linear(2, 2)
#  |          >>> net = nn.Sequential(l, l)
#  |          >>> for idx, m in enumerate(net.modules()):
#  |          ...     print(idx, '->', m)
#  |
#  |          0 -> Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          )
#  |          1 -> Linear(in_features=2, out_features=2, bias=True)
#  |
#  |  mtia(self: ~T, device: Union[int, torch.device, NoneType] = None) -> ~T
#  |      Move all model parameters and buffers to the MTIA.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on MTIA while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Arguments:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  named_buffers(self, prefix: str = '', recurse: bool = True, remove_duplicate: bool = True) -> Iterator[Tuple[str, torch.Tensor]]
#  |      Return an iterator over module buffers, yielding both the name of the buffer as well as the buffer itself.
#  |
#  |      Args:
#  |          prefix (str): prefix to prepend to all buffer names.
#  |          recurse (bool, optional): if True, then yields buffers of this module
#  |              and all submodules. Otherwise, yields only buffers that
#  |              are direct members of this module. Defaults to True.
#  |          remove_duplicate (bool, optional): whether to remove the duplicated buffers in the result. Defaults to True.
#  |
#  |      Yields:
#  |          (str, torch.Tensor): Tuple containing the name and buffer
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for name, buf in self.named_buffers():
#  |          >>>     if name in ['running_var']:
#  |          >>>         print(buf.size())
#  |
#  |  named_children(self) -> Iterator[Tuple[str, ForwardRef('Module')]]
#  |      Return an iterator over immediate children modules, yielding both the name of the module as well as the module itself.
#  |
#  |      Yields:
#  |          (str, Module): Tuple containing a name and child module
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for name, module in model.named_children():
#  |          >>>     if name in ['conv4', 'conv5']:
#  |          >>>         print(module)
#  |
#  |  named_modules(self, memo: Optional[Set[ForwardRef('Module')]] = None, prefix: str = '', remove_duplicate: bool = True)
#  |      Return an iterator over all modules in the network, yielding both the name of the module as well as the module itself.
#  |
#  |      Args:
#  |          memo: a memo to store the set of modules already added to the result
#  |          prefix: a prefix that will be added to the name of the module
#  |          remove_duplicate: whether to remove the duplicated module instances in the result
#  |              or not
#  |
#  |      Yields:
#  |          (str, Module): Tuple of name and module
#  |
#  |      Note:
#  |          Duplicate modules are returned only once. In the following
#  |          example, ``l`` will be returned only once.
#  |
#  |      Example::
#  |
#  |          >>> l = nn.Linear(2, 2)
#  |          >>> net = nn.Sequential(l, l)
#  |          >>> for idx, m in enumerate(net.named_modules()):
#  |          ...     print(idx, '->', m)
#  |
#  |          0 -> ('', Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          ))
#  |          1 -> ('0', Linear(in_features=2, out_features=2, bias=True))
#  |
#  |  named_parameters(self, prefix: str = '', recurse: bool = True, remove_duplicate: bool = True) -> Iterator[Tuple[str, torch.nn.parameter.Parameter]]
#  |      Return an iterator over module parameters, yielding both the name of the parameter as well as the parameter itself.
#  |
#  |      Args:
#  |          prefix (str): prefix to prepend to all parameter names.
#  |          recurse (bool): if True, then yields parameters of this module
#  |              and all submodules. Otherwise, yields only parameters that
#  |              are direct members of this module.
#  |          remove_duplicate (bool, optional): whether to remove the duplicated
#  |              parameters in the result. Defaults to True.
#  |
#  |      Yields:
#  |          (str, Parameter): Tuple containing the name and parameter
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for name, param in self.named_parameters():
#  |          >>>     if name in ['bias']:
#  |          >>>         print(param.size())
#  |
#  |  parameters(self, recurse: bool = True) -> Iterator[torch.nn.parameter.Parameter]
#  |      Return an iterator over module parameters.
#  |
#  |      This is typically passed to an optimizer.
#  |
#  |      Args:
#  |          recurse (bool): if True, then yields parameters of this module
#  |              and all submodules. Otherwise, yields only parameters that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          Parameter: module parameter
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for param in model.parameters():
#  |          >>>     print(type(param), param.size())
#  |          <class 'torch.Tensor'> (20L,)
#  |          <class 'torch.Tensor'> (20L, 1L, 5L, 5L)
#  |
#  |  register_backward_hook(self, hook: Callable[[ForwardRef('Module'), Union[Tuple[torch.Tensor, ...], torch.Tensor], Union[Tuple[torch.Tensor, ...], torch.Tensor]], Union[NoneType, Tuple[torch.Tensor, ...], torch.Tensor]]) -> torch.utils.hooks.RemovableHandle
#  |      Register a backward hook on the module.
#  |
#  |      This function is deprecated in favor of :meth:`~torch.nn.Module.register_full_backward_hook` and
#  |      the behavior of this function will change in future versions.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_buffer(self, name: str, tensor: Optional[torch.Tensor], persistent: bool = True) -> None
#  |      Add a buffer to the module.
#  |
#  |      This is typically used to register a buffer that should not to be
#  |      considered a model parameter. For example, BatchNorm's ``running_mean``
#  |      is not a parameter, but is part of the module's state. Buffers, by
#  |      default, are persistent and will be saved alongside parameters. This
#  |      behavior can be changed by setting :attr:`persistent` to ``False``. The
#  |      only difference between a persistent buffer and a non-persistent buffer
#  |      is that the latter will not be a part of this module's
#  |      :attr:`state_dict`.
#  |
#  |      Buffers can be accessed as attributes using given names.
#  |
#  |      Args:
#  |          name (str): name of the buffer. The buffer can be accessed
#  |              from this module using the given name
#  |          tensor (Tensor or None): buffer to be registered. If ``None``, then operations
#  |              that run on buffers, such as :attr:`cuda`, are ignored. If ``None``,
#  |              the buffer is **not** included in the module's :attr:`state_dict`.
#  |          persistent (bool): whether the buffer is part of this module's
#  |              :attr:`state_dict`.
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> self.register_buffer('running_mean', torch.zeros(num_features))
#  |
#  |  register_forward_hook(self, hook: Union[Callable[[~T, Tuple[Any, ...], Any], Optional[Any]], Callable[[~T, Tuple[Any, ...], Dict[str, Any], Any], Optional[Any]]], *, prepend: bool = False, with_kwargs: bool = False, always_call: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Register a forward hook on the module.
#  |
#  |      The hook will be called every time after :func:`forward` has computed an output.
#  |
#  |      If ``with_kwargs`` is ``False`` or not specified, the input contains only
#  |      the positional arguments given to the module. Keyword arguments won't be
#  |      passed to the hooks and only to the ``forward``. The hook can modify the
#  |      output. It can modify the input inplace but it will not have effect on
#  |      forward since this is called after :func:`forward` is called. The hook
#  |      should have the following signature::
#  |
#  |          hook(module, args, output) -> None or modified output
#  |
#  |      If ``with_kwargs`` is ``True``, the forward hook will be passed the
#  |      ``kwargs`` given to the forward function and be expected to return the
#  |      output possibly modified. The hook should have the following signature::
#  |
#  |          hook(module, args, kwargs, output) -> None or modified output
#  |
#  |      Args:
#  |          hook (Callable): The user defined hook to be registered.
#  |          prepend (bool): If ``True``, the provided ``hook`` will be fired
#  |              before all existing ``forward`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``forward`` hooks on
#  |              this :class:`torch.nn.modules.Module`. Note that global
#  |              ``forward`` hooks registered with
#  |              :func:`register_module_forward_hook` will fire before all hooks
#  |              registered by this method.
#  |              Default: ``False``
#  |          with_kwargs (bool): If ``True``, the ``hook`` will be passed the
#  |              kwargs given to the forward function.
#  |              Default: ``False``
#  |          always_call (bool): If ``True`` the ``hook`` will be run regardless of
#  |              whether an exception is raised while calling the Module.
#  |              Default: ``False``
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_forward_pre_hook(self, hook: Union[Callable[[~T, Tuple[Any, ...]], Optional[Any]], Callable[[~T, Tuple[Any, ...], Dict[str, Any]], Optional[Tuple[Any, Dict[str, Any]]]]], *, prepend: bool = False, with_kwargs: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Register a forward pre-hook on the module.
#  |
#  |      The hook will be called every time before :func:`forward` is invoked.
#  |
#  |
#  |      If ``with_kwargs`` is false or not specified, the input contains only
#  |      the positional arguments given to the module. Keyword arguments won't be
#  |      passed to the hooks and only to the ``forward``. The hook can modify the
#  |      input. User can either return a tuple or a single modified value in the
#  |      hook. We will wrap the value into a tuple if a single value is returned
#  |      (unless that value is already a tuple). The hook should have the
#  |      following signature::
#  |
#  |          hook(module, args) -> None or modified input
#  |
#  |      If ``with_kwargs`` is true, the forward pre-hook will be passed the
#  |      kwargs given to the forward function. And if the hook modifies the
#  |      input, both the args and kwargs should be returned. The hook should have
#  |      the following signature::
#  |
#  |          hook(module, args, kwargs) -> None or a tuple of modified input and kwargs
#  |
#  |      Args:
#  |          hook (Callable): The user defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``forward_pre`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``forward_pre`` hooks
#  |              on this :class:`torch.nn.modules.Module`. Note that global
#  |              ``forward_pre`` hooks registered with
#  |              :func:`register_module_forward_pre_hook` will fire before all
#  |              hooks registered by this method.
#  |              Default: ``False``
#  |          with_kwargs (bool): If true, the ``hook`` will be passed the kwargs
#  |              given to the forward function.
#  |              Default: ``False``
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_full_backward_hook(self, hook: Callable[[ForwardRef('Module'), Union[Tuple[torch.Tensor, ...], torch.Tensor], Union[Tuple[torch.Tensor, ...], torch.Tensor]], Union[NoneType, Tuple[torch.Tensor, ...], torch.Tensor]], prepend: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Register a backward hook on the module.
#  |
#  |      The hook will be called every time the gradients with respect to a module
#  |      are computed, i.e. the hook will execute if and only if the gradients with
#  |      respect to module outputs are computed. The hook should have the following
#  |      signature::
#  |
#  |          hook(module, grad_input, grad_output) -> tuple(Tensor) or None
#  |
#  |      The :attr:`grad_input` and :attr:`grad_output` are tuples that contain the gradients
#  |      with respect to the inputs and outputs respectively. The hook should
#  |      not modify its arguments, but it can optionally return a new gradient with
#  |      respect to the input that will be used in place of :attr:`grad_input` in
#  |      subsequent computations. :attr:`grad_input` will only correspond to the inputs given
#  |      as positional arguments and all kwarg arguments are ignored. Entries
#  |      in :attr:`grad_input` and :attr:`grad_output` will be ``None`` for all non-Tensor
#  |      arguments.
#  |
#  |      For technical reasons, when this hook is applied to a Module, its forward function will
#  |      receive a view of each Tensor passed to the Module. Similarly the caller will receive a view
#  |      of each Tensor returned by the Module's forward function.
#  |
#  |      .. warning ::
#  |          Modifying inputs or outputs inplace is not allowed when using backward hooks and
#  |          will raise an error.
#  |
#  |      Args:
#  |          hook (Callable): The user-defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``backward`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``backward`` hooks on
#  |              this :class:`torch.nn.modules.Module`. Note that global
#  |              ``backward`` hooks registered with
#  |              :func:`register_module_full_backward_hook` will fire before
#  |              all hooks registered by this method.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_full_backward_pre_hook(self, hook: Callable[[ForwardRef('Module'), Union[Tuple[torch.Tensor, ...], torch.Tensor]], Union[NoneType, Tuple[torch.Tensor, ...], torch.Tensor]], prepend: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Register a backward pre-hook on the module.
#  |
#  |      The hook will be called every time the gradients for the module are computed.
#  |      The hook should have the following signature::
#  |
#  |          hook(module, grad_output) -> tuple[Tensor] or None
#  |
#  |      The :attr:`grad_output` is a tuple. The hook should
#  |      not modify its arguments, but it can optionally return a new gradient with
#  |      respect to the output that will be used in place of :attr:`grad_output` in
#  |      subsequent computations. Entries in :attr:`grad_output` will be ``None`` for
#  |      all non-Tensor arguments.
#  |
#  |      For technical reasons, when this hook is applied to a Module, its forward function will
#  |      receive a view of each Tensor passed to the Module. Similarly the caller will receive a view
#  |      of each Tensor returned by the Module's forward function.
#  |
#  |      .. warning ::
#  |          Modifying inputs inplace is not allowed when using backward hooks and
#  |          will raise an error.
#  |
#  |      Args:
#  |          hook (Callable): The user-defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``backward_pre`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``backward_pre`` hooks
#  |              on this :class:`torch.nn.modules.Module`. Note that global
#  |              ``backward_pre`` hooks registered with
#  |              :func:`register_module_full_backward_pre_hook` will fire before
#  |              all hooks registered by this method.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_load_state_dict_post_hook(self, hook)
#  |      Register a post-hook to be run after module's :meth:`~nn.Module.load_state_dict` is called.
#  |
#  |      It should have the following signature::
#  |          hook(module, incompatible_keys) -> None
#  |
#  |      The ``module`` argument is the current module that this hook is registered
#  |      on, and the ``incompatible_keys`` argument is a ``NamedTuple`` consisting
#  |      of attributes ``missing_keys`` and ``unexpected_keys``. ``missing_keys``
#  |      is a ``list`` of ``str`` containing the missing keys and
#  |      ``unexpected_keys`` is a ``list`` of ``str`` containing the unexpected keys.
#  |
#  |      The given incompatible_keys can be modified inplace if needed.
#  |
#  |      Note that the checks performed when calling :func:`load_state_dict` with
#  |      ``strict=True`` are affected by modifications the hook makes to
#  |      ``missing_keys`` or ``unexpected_keys``, as expected. Additions to either
#  |      set of keys will result in an error being thrown when ``strict=True``, and
#  |      clearing out both missing and unexpected keys will avoid an error.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_load_state_dict_pre_hook(self, hook)
#  |      Register a pre-hook to be run before module's :meth:`~nn.Module.load_state_dict` is called.
#  |
#  |      It should have the following signature::
#  |          hook(module, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs) -> None  # noqa: B950
#  |
#  |      Arguments:
#  |          hook (Callable): Callable hook that will be invoked before
#  |              loading the state dict.
#  |
#  |  register_module(self, name: str, module: Optional[ForwardRef('Module')]) -> None
#  |      Alias for :func:`add_module`.
#  |
#  |  register_parameter(self, name: str, param: Optional[torch.nn.parameter.Parameter]) -> None
#  |      Add a parameter to the module.
#  |
#  |      The parameter can be accessed as an attribute using given name.
#  |
#  |      Args:
#  |          name (str): name of the parameter. The parameter can be accessed
#  |              from this module using the given name
#  |          param (Parameter or None): parameter to be added to the module. If
#  |              ``None``, then operations that run on parameters, such as :attr:`cuda`,
#  |              are ignored. If ``None``, the parameter is **not** included in the
#  |              module's :attr:`state_dict`.
#  |
#  |  register_state_dict_post_hook(self, hook)
#  |      Register a post-hook for the :meth:`~torch.nn.Module.state_dict` method.
#  |
#  |      It should have the following signature::
#  |          hook(module, state_dict, prefix, local_metadata) -> None
#  |
#  |      The registered hooks can modify the ``state_dict`` inplace.
#  |
#  |  register_state_dict_pre_hook(self, hook)
#  |      Register a pre-hook for the :meth:`~torch.nn.Module.state_dict` method.
#  |
#  |      It should have the following signature::
#  |          hook(module, prefix, keep_vars) -> None
#  |
#  |      The registered hooks can be used to perform pre-processing before the ``state_dict``
#  |      call is made.
#  |
#  |  requires_grad_(self: ~T, requires_grad: bool = True) -> ~T
#  |      Change if autograd should record operations on parameters in this module.
#  |
#  |      This method sets the parameters' :attr:`requires_grad` attributes
#  |      in-place.
#  |
#  |      This method is helpful for freezing part of the module for finetuning
#  |      or training parts of a model individually (e.g., GAN training).
#  |
#  |      See :ref:`locally-disable-grad-doc` for a comparison between
#  |      `.requires_grad_()` and several similar mechanisms that may be confused with it.
#  |
#  |      Args:
#  |          requires_grad (bool): whether autograd should record operations on
#  |                                parameters in this module. Default: ``True``.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  set_extra_state(self, state: Any) -> None
#  |      Set extra state contained in the loaded `state_dict`.
#  |
#  |      This function is called from :func:`load_state_dict` to handle any extra state
#  |      found within the `state_dict`. Implement this function and a corresponding
#  |      :func:`get_extra_state` for your module if you need to store extra state within its
#  |      `state_dict`.
#  |
#  |      Args:
#  |          state (dict): Extra state from the `state_dict`
#  |
#  |  set_submodule(self, target: str, module: 'Module') -> None
#  |      Set the submodule given by ``target`` if it exists, otherwise throw an error.
#  |
#  |      For example, let's say you have an ``nn.Module`` ``A`` that
#  |      looks like this:
#  |
#  |      .. code-block:: text
#  |
#  |          A(
#  |              (net_b): Module(
#  |                  (net_c): Module(
#  |                      (conv): Conv2d(16, 33, kernel_size=(3, 3), stride=(2, 2))
#  |                  )
#  |                  (linear): Linear(in_features=100, out_features=200, bias=True)
#  |              )
#  |          )
#  |
#  |      (The diagram shows an ``nn.Module`` ``A``. ``A`` has a nested
#  |      submodule ``net_b``, which itself has two submodules ``net_c``
#  |      and ``linear``. ``net_c`` then has a submodule ``conv``.)
#  |
#  |      To overide the ``Conv2d`` with a new submodule ``Linear``, you
#  |      would call
#  |      ``set_submodule("net_b.net_c.conv", nn.Linear(33, 16))``.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the submodule
#  |              to look for. (See above example for how to specify a
#  |              fully-qualified string.)
#  |          module: The module to set the submodule to.
#  |
#  |      Raises:
#  |          ValueError: If the target string is empty
#  |          AttributeError: If the target string references an invalid
#  |              path or resolves to something that is not an
#  |              ``nn.Module``
#  |
#  |  share_memory(self: ~T) -> ~T
#  |      See :meth:`torch.Tensor.share_memory_`.
#  |
#  |  state_dict(self, *args, destination=None, prefix='', keep_vars=False)
#  |      Return a dictionary containing references to the whole state of the module.
#  |
#  |      Both parameters and persistent buffers (e.g. running averages) are
#  |      included. Keys are corresponding parameter and buffer names.
#  |      Parameters and buffers set to ``None`` are not included.
#  |
#  |      .. note::
#  |          The returned object is a shallow copy. It contains references
#  |          to the module's parameters and buffers.
#  |
#  |      .. warning::
#  |          Currently ``state_dict()`` also accepts positional arguments for
#  |          ``destination``, ``prefix`` and ``keep_vars`` in order. However,
#  |          this is being deprecated and keyword arguments will be enforced in
#  |          future releases.
#  |
#  |      .. warning::
#  |          Please avoid the use of argument ``destination`` as it is not
#  |          designed for end-users.
#  |
#  |      Args:
#  |          destination (dict, optional): If provided, the state of module will
#  |              be updated into the dict and the same object is returned.
#  |              Otherwise, an ``OrderedDict`` will be created and returned.
#  |              Default: ``None``.
#  |          prefix (str, optional): a prefix added to parameter and buffer
#  |              names to compose the keys in state_dict. Default: ``''``.
#  |          keep_vars (bool, optional): by default the :class:`~torch.Tensor` s
#  |              returned in the state dict are detached from autograd. If it's
#  |              set to ``True``, detaching will not be performed.
#  |              Default: ``False``.
#  |
#  |      Returns:
#  |          dict:
#  |              a dictionary containing a whole state of the module
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> module.state_dict().keys()
#  |          ['bias', 'weight']
#  |
#  |  to(self, *args, **kwargs)
#  |      Move and/or cast the parameters and buffers.
#  |
#  |      This can be called as
#  |
#  |      .. function:: to(device=None, dtype=None, non_blocking=False)
#  |         :noindex:
#  |
#  |      .. function:: to(dtype, non_blocking=False)
#  |         :noindex:
#  |
#  |      .. function:: to(tensor, non_blocking=False)
#  |         :noindex:
#  |
#  |      .. function:: to(memory_format=torch.channels_last)
#  |         :noindex:
#  |
#  |      Its signature is similar to :meth:`torch.Tensor.to`, but only accepts
#  |      floating point or complex :attr:`dtype`\ s. In addition, this method will
#  |      only cast the floating point or complex parameters and buffers to :attr:`dtype`
#  |      (if given). The integral parameters and buffers will be moved
#  |      :attr:`device`, if that is given, but with dtypes unchanged. When
#  |      :attr:`non_blocking` is set, it tries to convert/move asynchronously
#  |      with respect to the host if possible, e.g., moving CPU Tensors with
#  |      pinned memory to CUDA devices.
#  |
#  |      See below for examples.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Args:
#  |          device (:class:`torch.device`): the desired device of the parameters
#  |              and buffers in this module
#  |          dtype (:class:`torch.dtype`): the desired floating point or complex dtype of
#  |              the parameters and buffers in this module
#  |          tensor (torch.Tensor): Tensor whose dtype and device are the desired
#  |              dtype and device for all parameters and buffers in this module
#  |          memory_format (:class:`torch.memory_format`): the desired memory
#  |              format for 4D parameters and buffers in this module (keyword
#  |              only argument)
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |      Examples::
#  |
#  |          >>> # xdoctest: +IGNORE_WANT("non-deterministic")
#  |          >>> linear = nn.Linear(2, 2)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1913, -0.3420],
#  |                  [-0.5113, -0.2325]])
#  |          >>> linear.to(torch.double)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1913, -0.3420],
#  |                  [-0.5113, -0.2325]], dtype=torch.float64)
#  |          >>> # xdoctest: +REQUIRES(env:TORCH_DOCTEST_CUDA1)
#  |          >>> gpu1 = torch.device("cuda:1")
#  |          >>> linear.to(gpu1, dtype=torch.half, non_blocking=True)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1914, -0.3420],
#  |                  [-0.5112, -0.2324]], dtype=torch.float16, device='cuda:1')
#  |          >>> cpu = torch.device("cpu")
#  |          >>> linear.to(cpu)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1914, -0.3420],
#  |                  [-0.5112, -0.2324]], dtype=torch.float16)
#  |
#  |          >>> linear = nn.Linear(2, 2, bias=None).to(torch.cdouble)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.3741+0.j,  0.2382+0.j],
#  |                  [ 0.5593+0.j, -0.4443+0.j]], dtype=torch.complex128)
#  |          >>> linear(torch.ones(3, 2, dtype=torch.cdouble))
#  |          tensor([[0.6122+0.j, 0.1150+0.j],
#  |                  [0.6122+0.j, 0.1150+0.j],
#  |                  [0.6122+0.j, 0.1150+0.j]], dtype=torch.complex128)
#  |
#  |  to_empty(self: ~T, *, device: Union[int, str, torch.device, NoneType], recurse: bool = True) -> ~T
#  |      Move the parameters and buffers to the specified device without copying storage.
#  |
#  |      Args:
#  |          device (:class:`torch.device`): The desired device of the parameters
#  |              and buffers in this module.
#  |          recurse (bool): Whether parameters and buffers of submodules should
#  |              be recursively moved to the specified device.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  train(self: ~T, mode: bool = True) -> ~T
#  |      Set the module in training mode.
#  |
#  |      This has any effect only on certain modules. See documentations of
#  |      particular modules for details of their behaviors in training/evaluation
#  |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#  |      etc.
#  |
#  |      Args:
#  |          mode (bool): whether to set training mode (``True``) or evaluation
#  |                       mode (``False``). Default: ``True``.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  type(self: ~T, dst_type: Union[torch.dtype, str]) -> ~T
#  |      Casts all parameters and buffers to :attr:`dst_type`.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Args:
#  |          dst_type (type or string): the desired type
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  xpu(self: ~T, device: Union[int, torch.device, NoneType] = None) -> ~T
#  |      Move all model parameters and buffers to the XPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on XPU while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Arguments:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  zero_grad(self, set_to_none: bool = True) -> None
#  |      Reset gradients of all model parameters.
#  |
#  |      See similar function under :class:`torch.optim.Optimizer` for more context.
#  |
#  |      Args:
#  |          set_to_none (bool): instead of setting to zero, set the grads to None.
#  |              See :meth:`torch.optim.Optimizer.zero_grad` for details.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from torch.nn.modules.module.Module:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from torch.nn.modules.module.Module:
#  |
#  |  T_destination = ~T_destination
#  |
#  |  call_super_init = False
#  |
#  |  dump_patches = False

# %% [markdown]
# Szczególnie interesującym będzie dla nas argument `net_arch`, definiujący architekturę modelu strategii (jest to lista integerów, opisująca liczbę neuronów w poszczególnych warstwach ukrytych).

# %% [markdown]
# Deklarujemy funkcję do wyświetlania działania modelu. Poza tworzeniem animacji wykonuje ona również ewaluację modelu, sprawdzając w 100 epizodach osiąganą całkowitą wartość zwrotu.
#
# Sprawdzimy od razu, jak zachowuje się niewytrenowany (losowy) model (zwróćmy uwagę, że musimy podać model strategii, jak i środowisko, w jakim model ma działać - możemy uzyskać do niego dostęp wywołując metodę modelu `get_env`).

# %%
def visualize_model(model, max_steps=50):
    """Show how a model works in the environment."""
    env = model.get_env()
    obs = env.reset()

    fig, ax = plt.subplots()
    frames = []
    done = False

    while not done:
        f = env.render(mode="rgb_array")
        if f is not None:
            frames.append(f.astype(np.uint8))
        with torch.no_grad():
            action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        if len(frames) >= max_steps:
            break

    anim = animation.FuncAnimation(
        fig=fig,
        func=lambda i: ax.imshow(frames[i]),
        frames=range(len(frames)),
        interval=100,
        blit=False,
    )
    plt.close()

    reward_avg, reward_std = evaluate_policy(model, env, n_eval_episodes=100)
    print(f"Reward in episode: {reward_avg:.2f} +/- {reward_std:.2f}")

    return anim.to_jshtml()


env = gym.make("CartPole-v1", render_mode="rgb_array")
model = DQN(MlpPolicy, env)
display(ipythondisplay.HTML(visualize_model(model)))
# Out:
# Reward in episode: 9.24 +/- 0.68
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc9895f736f3c4091baae433e0a5ab571">
#   <div class="anim-controls">
#     <input id="_anim_sliderc9895f736f3c4091baae433e0a5ab571" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc9895f736f3c4091baae433e0a5ab571.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animc9895f736f3c4091baae433e0a5ab571.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animc9895f736f3c4091baae433e0a5ab571.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animc9895f736f3c4091baae433e0a5ab571.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animc9895f736f3c4091baae433e0a5ab571.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animc9895f736f3c4091baae433e0a5ab571.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animc9895f736f3c4091baae433e0a5ab571.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animc9895f736f3c4091baae433e0a5ab571.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animc9895f736f3c4091baae433e0a5ab571.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animc9895f736f3c4091baae433e0a5ab571.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectc9895f736f3c4091baae433e0a5ab571"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c9895f736f3c4091baae433e0a5ab571"
#              >
#       <label for="_anim_radio1_c9895f736f3c4091baae433e0a5ab571">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c9895f736f3c4091baae433e0a5ab571"
#              checked>
#       <label for="_anim_radio2_c9895f736f3c4091baae433e0a5ab571">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c9895f736f3c4091baae433e0a5ab571"
#              >
#       <label for="_anim_radio3_c9895f736f3c4091baae433e0a5ab571">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc9895f736f3c4091baae433e0a5ab571";
#     var slider_id = "_anim_sliderc9895f736f3c4091baae433e0a5ab571";
#     var loop_select_id = "_anim_loop_selectc9895f736f3c4091baae433e0a5ab571";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjksIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvJkbTWQAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAKxJJR

# %% [markdown]
# Zaczniemy od deklaracji uproszczonego modelu, ze stałą wartością $\epsilon$, bez target network oraz z experience replay o długości batcha (efektywnie - brakiem experience replay). Następnie będziemy chcieli włączać ulepszenia oraz stroić hiperparametry aby sprawdzić, jak wpływają one na działanie modelu. Do wytrenowania modelu służy metoda `learn`. Sprawdźmy jej parametry.

# %%
help(DQN.learn)
# Out:
# Help on function learn in module stable_baselines3.dqn.dqn:
#
# learn(self: ~SelfDQN, total_timesteps: int, callback: Union[NoneType, collections.abc.Callable, list['BaseCallback'], ForwardRef('BaseCallback')] = None, log_interval: int = 4, tb_log_name: str = 'DQN', reset_num_timesteps: bool = True, progress_bar: bool = False) -> ~SelfDQN
#     Return a trained model.
#
#     :param total_timesteps: The total number of samples (env steps) to train on
#         Note: it is a lower bound, see `issue #1150 <https://github.com/DLR-RM/stable-baselines3/issues/1150>`_
#     :param callback: callback(s) called at every step with state of the algorithm.
#     :param log_interval: for on-policy algos (e.g., PPO, A2C, ...) this is the number of
#         training iterations (i.e., log_interval * n_steps * n_envs timesteps) before logging;
#         for off-policy algos (e.g., TD3, SAC, ...) this is the number of episodes before
#         logging.
#     :param tb_log_name: the name of the run for TensorBoard logging
#     :param reset_num_timesteps: whether or not to reset the current timestep number (used in logging)
#     :param progress_bar: Display a progress bar using tqdm and rich.
#     :return: the trained model

# %% [markdown]
# Z punktu widzenia analizy działania modelu potrzebna jest jedynie liczba kroków uczenia `total_timesteps`. Możemy też wyregulować częstość ewaluacji oraz logowania (wyświetlanie logu odbywa się jedynie przy ustawieniu `verbose=1`). Oprócz tego chcielibyśmy jednak także wyświetlić krzywą uczenia. Wykorzystujemy w tym celu wrapper na środowisko w Unity `Monitor`. Jako parametry przyjmuje on środowisko, które będziemy monitorować, oraz folder, w którym będziemy zapisywać logi. Możemy je potem wczytać i wyświetlić wykorzystując metody `load_results` i `plot_results`.

# %%
RESULTS_DIR = "/tmp/"

env = Monitor(env, filename=RESULTS_DIR)

# %% [markdown]
# Deklarujemy model. Ustawiając rozmiar bufora oraz start i częstość trenowania równe wielkości mini-batcha efektywnie wyłączamy experience replay, a aktualizując sieć w interwale równym wielkości batcha model trenowany będzie bez *target network*. Ponadto, dobieramy odpowiednio wartości schedulera $\epsilon$, tak, aby współczynnik ten był stały podczas trenowania.

# %%
batch_size = 64
lr = 1e-4
gamma = 0.8
eps = 0.1

env = gym.make("CartPole-v1")
log_dir = "/tmp/vanilla/"
os.makedirs(log_dir, exist_ok=True)  # we have to create this dir - it does not exist
env = Monitor(env, filename=log_dir)

vanilla_dqn = DQN(
    MlpPolicy, env,
    learning_rate=lr, batch_size=batch_size, gamma=gamma, seed=SEED,
    buffer_size=batch_size, learning_starts=batch_size, train_freq=batch_size,  # disable experience replay
    target_update_interval=batch_size,  # disable target network
    exploration_fraction=1, exploration_initial_eps=eps, exploration_final_eps=eps,  # disable epsilon scheduling
    verbose=1,  # show information throughout training
)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# Wytrenujmy zatem taki prosty model w 100 000 kroków i sprawdźmy jakie osiągnie on po tym czasie rezultaty.

# %%
total_timesteps = 100000

vanilla_dqn.learn(total_timesteps)
display(ipythondisplay.HTML(visualize_model(vanilla_dqn)))
plot_results([log_dir], total_timesteps, "timesteps", "Vanilla DQN")
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1446     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1191     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 116      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 314      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 156      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.52     |
# |    n_updates        | 1        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 357      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 194      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.524    |
# |    n_updates        | 2        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 395      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 234      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 421      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 273      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.489    |
# |    n_updates        | 3        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 451      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 469      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 350      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.505    |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 482      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 389      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.478    |
# |    n_updates        | 5        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 503      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 432      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 512      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 469      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.525    |
# |    n_updates        | 6        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 521      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 536      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 549      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.484    |
# |    n_updates        | 7        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 549      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 591      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.483    |
# |    n_updates        | 8        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 566      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 631      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 584      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 676      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 9        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 600      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 719      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.506    |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 612      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 757      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 623      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 795      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.47     |
# |    n_updates        | 11       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 836      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.488    |
# |    n_updates        | 12       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 651      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 876      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 662      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 921      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.489    |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 668      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 956      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 676      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 998      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.476    |
# |    n_updates        | 14       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 685      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1039     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.493    |
# |    n_updates        | 15       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 698      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 701      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1123     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.484    |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 707      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.479    |
# |    n_updates        | 17       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 715      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 722      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1240     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.511    |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 731      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 737      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1320     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.458    |
# |    n_updates        | 19       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 740      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1357     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.468    |
# |    n_updates        | 20       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 748      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 753      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1436     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.483    |
# |    n_updates        | 21       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 758      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1479     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 760      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1520     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 764      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1562     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.477    |
# |    n_updates        | 23       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 770      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 773      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1636     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.462    |
# |    n_updates        | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 776      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1672     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.47     |
# |    n_updates        | 25       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 783      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 788      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1754     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.503    |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 790      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 796      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1836     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.487    |
# |    n_updates        | 27       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 800      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1877     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.456    |
# |    n_updates        | 28       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 805      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 792      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1949     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.493    |
# |    n_updates        | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.88     |
# |    ep_rew_mean      | 9.88     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 790      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1986     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.456    |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.86     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 795      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 796      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2061     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.464    |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 800      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 799      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2136     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.456    |
# |    n_updates        | 32       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 804      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 809      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2215     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.475    |
# |    n_updates        | 33       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 811      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2254     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.467    |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 816      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 820      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2334     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 821      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2372     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.445    |
# |    n_updates        | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.7      |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 825      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 824      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2447     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.473    |
# |    n_updates        | 37       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.64     |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 826      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2484     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.65     |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 828      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2527     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.437    |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.65     |
# |    ep_rew_mean      | 9.65     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 826      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2565     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.448    |
# |    n_updates        | 39       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 832      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 835      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2653     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.495    |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 835      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2690     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.485    |
# |    n_updates        | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 836      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 835      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2767     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.482    |
# |    n_updates        | 42       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 840      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 839      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2846     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.516    |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 9.72     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 834      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2886     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.444    |
# |    n_updates        | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 835      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 835      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2961     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.496    |
# |    n_updates        | 45       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.74     |
# |    ep_rew_mean      | 9.74     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 831      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82     |
# |    ep_rew_mean      | 9.82     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 829      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3043     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82     |
# |    ep_rew_mean      | 9.82     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 830      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3081     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.464    |
# |    n_updates        | 47       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.86     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 821      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 822      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3159     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.83     |
# |    ep_rew_mean      | 9.83     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 824      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82     |
# |    ep_rew_mean      | 9.82     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 824      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3236     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.445    |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 825      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3276     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.442    |
# |    n_updates        | 50       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.84     |
# |    ep_rew_mean      | 9.84     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 829      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.85     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 831      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3357     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.455    |
# |    n_updates        | 51       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.91     |
# |    ep_rew_mean      | 9.91     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 831      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3397     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.463    |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 835      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.99     |
# |    ep_rew_mean      | 9.99     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 837      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3483     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.463    |
# |    n_updates        | 53       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 838      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3523     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.438    |
# |    n_updates        | 54       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 842      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 843      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3604     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.448    |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 847      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3646     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 850      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3687     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.489    |
# |    n_updates        | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 850      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3724     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.45     |
# |    n_updates        | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.99     |
# |    ep_rew_mean      | 9.99     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 852      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 853      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3805     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.465    |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.99     |
# |    ep_rew_mean      | 9.99     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 855      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3845     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.463    |
# |    n_updates        | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 857      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.98     |
# |    ep_rew_mean      | 9.98     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 856      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3922     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.458    |
# |    n_updates        | 60       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 858      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 857      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3996     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.457    |
# |    n_updates        | 61       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.91     |
# |    ep_rew_mean      | 9.91     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 855      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4034     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.438    |
# |    n_updates        | 62       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 856      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4074     |
# ----------------------------------
# ----------------------------------
# ...
# |    loss             | 0.0597   |
# |    n_updates        | 1552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.79     |
# |    ep_rew_mean      | 9.79     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10072    |
# |    fps              | 924      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.78     |
# |    ep_rew_mean      | 9.78     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10076    |
# |    fps              | 924      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0982   |
# |    n_updates        | 1553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10080    |
# |    fps              | 924      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10084    |
# |    fps              | 924      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99559    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 1554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10088    |
# |    fps              | 924      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.144    |
# |    n_updates        | 1555     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10092    |
# |    fps              | 924      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.86     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10096    |
# |    fps              | 923      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0643   |
# |    n_updates        | 1556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.83     |
# |    ep_rew_mean      | 9.83     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10100    |
# |    fps              | 923      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 99720    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0535   |
# |    n_updates        | 1557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.83     |
# |    ep_rew_mean      | 9.83     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10104    |
# |    fps              | 923      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99759    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.86     |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10108    |
# |    fps              | 923      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99803    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0864   |
# |    n_updates        | 1558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 9.9      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10112    |
# |    fps              | 923      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99845    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0749   |
# |    n_updates        | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.89     |
# |    ep_rew_mean      | 9.89     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10116    |
# |    fps              | 923      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10120    |
# |    fps              | 923      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99925    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 1560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10124    |
# |    fps              | 923      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99970    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0452   |
# |    n_updates        | 1561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 10128    |
# |    fps              | 923      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 100011   |
# ----------------------------------
# C:\Users\48572\.conda\envs\deep_learning\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:249: UserWarning: Starting from gymnasium v0.26, render modes are determined during the initialization of the environment.
#                 We allow to pass a mode argument to maintain a backwards compatible VecEnv API, but the mode (rgb_array)
#                 has to be the same as the environment render mode (None) which is not the case.
#   warnings.warn(
# Reward in episode: 9.27 +/- 0.69
# C:\Users\48572\.conda\envs\deep_learning\Lib\site-packages\matplotlib\animation.py:1774: UserWarning: Can not start iterating the frames for the initial draw. This can be caused by passing in a 0 length sequence for *frames*.
#
# If you passed *frames* as a generator it may be exhausted due to a previous display or save.
#   warnings.warn(
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img6b521993810d41f6b536f1d48606426b">
#   <div class="anim-controls">
#     <input id="_anim_slider6b521993810d41f6b536f1d48606426b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim6b521993810d41f6b536f1d48606426b.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim6b521993810d41f6b536f1d48606426b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim6b521993810d41f6b536f1d48606426b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim6b521993810d41f6b536f1d48606426b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim6b521993810d41f6b536f1d48606426b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim6b521993810d41f6b536f1d48606426b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim6b521993810d41f6b536f1d48606426b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim6b521993810d41f6b536f1d48606426b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim6b521993810d41f6b536f1d48606426b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim6b521993810d41f6b536f1d48606426b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select6b521993810d41f6b536f1d48606426b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_6b521993810d41f6b536f1d48606426b"
#              >
#       <label for="_anim_radio1_6b521993810d41f6b536f1d48606426b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_6b521993810d41f6b536f1d48606426b"
#              checked>
#       <label for="_anim_radio2_6b521993810d41f6b536f1d48606426b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_6b521993810d41f6b536f1d48606426b"
#              >
#       <label for="_anim_radio3_6b521993810d41f6b536f1d48606426b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6b521993810d41f6b536f1d48606426b";
#     var slider_id = "_anim_slider6b521993810d41f6b536f1d48606426b";
#     var loop_select_id = "_anim_loop_select6b521993810d41f6b536f1d48606426b";
#     var frames = new Array(0);
#
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     s

# %% [markdown]
# Jak widać, metoda Deep Q-Learning w domyślnym ustawieniu nie działa zbyt dobrze - model nie zbiega, oscylując wokół początkowych wartości nagrody. Być może strojenie hiperparametrów poprawiłoby osiągane rezultaty?
#
# Sprawdźmy, jaka była maksymalna wartość zgromadzona w trakcie uczenia. Posłuży nam w tym celu funkcja `load_results`. Zwraca ona pandasowy DataFrame, w którym znajdują się informacje o każdym epizodzie w trakcie trenowania: uzyskanej nagrodzie `r`, długości epizodu `l` oraz jego czasie trwania `t`.

# %%
results = load_results(log_dir)
display(results.head(5))
print(f"Max reward: {results.r.max()}")
# Out:
#    index     r   l         t
# 0      0  14.0  14  0.123000
# 1      1  18.0  18  0.125017
# 2      2  12.0  12  0.126016
# 3      3  31.0  31  0.172359
# 4      4  11.0  11  0.186712
# Max reward: 31.0

# %% [markdown]
# Spróbujemy powtórzyć wytrenowanie modelu, tym razem z wykorzystaniem *experience replay*.

# %%
batch_size = 64
lr = 1e-4
gamma = 0.8

env = gym.make("CartPole-v1", render_mode="rgb_array")
log_dir = "/tmp/exp_replay/"
os.makedirs(log_dir, exist_ok=True)
env = Monitor(env, filename=log_dir)

dqn_exp = DQN(
    MlpPolicy, env,
    learning_rate=lr, batch_size=batch_size, gamma=gamma, seed=SEED,
    target_update_interval=batch_size,  # disable target network
    verbose=1,  # show information throughout training
)

total_timesteps = 100000

dqn_exp.learn(total_timesteps)
display(ipythondisplay.HTML(visualize_model(dqn_exp)))
plot_results([log_dir], total_timesteps, "timesteps", "DQN with experience replay")
results = load_results(log_dir)
print(f"Max reward: {results.r.max()}")
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 7810     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2411     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 129      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.695    |
# |    n_updates        | 7        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1532     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 191      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.596    |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1057     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 269      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.606    |
# |    n_updates        | 42       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 977      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 329      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.584    |
# |    n_updates        | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 882      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 432      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.554    |
# |    n_updates        | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 856      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 552      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.581    |
# |    n_updates        | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 806      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 625      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.511    |
# |    n_updates        | 131      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 769      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 747      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.516    |
# |    n_updates        | 161      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 752      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 830      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.486    |
# |    n_updates        | 182      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 748      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 920      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 204      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 734      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 995      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 223      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 722      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1068     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.443    |
# |    n_updates        | 241      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 718      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1137     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.417    |
# |    n_updates        | 259      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 715      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1231     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.425    |
# |    n_updates        | 282      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 610      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1324     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.409    |
# |    n_updates        | 305      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 545      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1401     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.371    |
# |    n_updates        | 325      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 503      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1476     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.409    |
# |    n_updates        | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 488      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1543     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.391    |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 492      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1633     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.407    |
# |    n_updates        | 383      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 498      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1723     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.366    |
# |    n_updates        | 405      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 500      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1824     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.386    |
# |    n_updates        | 430      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 500      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1890     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.383    |
# |    n_updates        | 447      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 503      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1943     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.37     |
# |    n_updates        | 460      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 506      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2015     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.388    |
# |    n_updates        | 478      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 508      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2077     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.488    |
# |    n_updates        | 494      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 511      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2133     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.372    |
# |    n_updates        | 508      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 515      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2225     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.315    |
# |    n_updates        | 531      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 517      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2296     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.47     |
# |    n_updates        | 548      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 520      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.436    |
# |    n_updates        | 567      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 524      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2483     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.528    |
# |    n_updates        | 595      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 526      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2572     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.428    |
# |    n_updates        | 617      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 528      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2658     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.226    |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 530      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2753     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.366    |
# |    n_updates        | 663      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 530      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2809     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.373    |
# |    n_updates        | 677      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 531      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2893     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.327    |
# |    n_updates        | 698      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 533      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2962     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.413    |
# |    n_updates        | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 533      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3026     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.508    |
# |    n_updates        | 731      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 535      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3104     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.358    |
# |    n_updates        | 750      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 507      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 3209     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.608    |
# |    n_updates        | 777      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 490      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 3269     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.321    |
# |    n_updates        | 792      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 465      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.409    |
# |    n_updates        | 817      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 453      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3426     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.34     |
# |    n_updates        | 831      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 440      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3484     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.554    |
# |    n_updates        | 845      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.663    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 439      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3547     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.551    |
# |    n_updates        | 861      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 440      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3595     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.992    |
# |    n_updates        | 873      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 441      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3655     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.722    |
# |    n_updates        | 888      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 444      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3741     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.585    |
# |    n_updates        | 910      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 444      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3799     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.155    |
# |    n_updates        | 924      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 445      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3850     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.565    |
# |    n_updates        | 937      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 446      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3906     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.399    |
# |    n_updates        | 951      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 447      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3961     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.856    |
# |    n_updates        | 965      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 448      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 4022     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0692   |
# |    n_updates        | 980      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 449      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4069     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.201    |
# |    n_updates        | 992      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 450      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4116     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.338    |
# |    n_updates        | 1003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 451      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4177     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0619   |
# |    n_updates        | 1019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 453      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4240     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 1034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 454      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4288     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.369    |
# |    n_updates        | 1046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 454      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4330     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.797    |
# |    n_updates        | 1057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 455      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4379     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.727    |
# |    n_updates        | 1069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 456      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4435     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.544    |
# |    n_updates        | 1083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 457      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4476     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.787    |
# |    n_updates        | 1093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 457      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4556     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.476    |
# |    n_updates        | 1113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 445      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4625     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.741    |
# |    n_updates        | 1131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 442      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4689     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.381    |
# |    n_updates        | 1147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 443      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4756     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.4      |
# |    n_updates        | 1163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 443      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4804     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.506    |
# |    n_updates        | 1175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 444      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4856     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.541    |
# |    n_updates        | 1188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 445      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4904     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.644    |
# |    n_updates        | 1200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 445      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4953     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.809    |
# |    n_updates        | 1213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 446      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5014     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.658    |
# |    n_updates        | 1228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 446      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5059     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.451    |
# |    n_updates        | 1239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 445      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5111     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.554    |
# |    n_updates        | 1252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 446      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5162     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.345    |
# |    n_updates        | 1265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 448      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5225     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.359    |
# |    n_updates        | 1281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 447      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5277     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.2      |
# |    n_updates        | 1294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 448      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5318     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.465    |
# |    n_updates        | 1304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.49     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 448      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 5368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.253    |
# |    n_updates        | 1316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 449      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5417     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.344    |
# |    n_updates        | 1329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 450      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5466     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.449    |
# |    n_updates        | 1341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 451      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5512     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.67     |
# |    n_updates        | 1352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 451      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5561     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00421  |
# |    n_updates        | 1365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 451      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5602     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0769   |
# |    n_updates        | 1375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 451      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5647     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.235    |
# |    n_updates        | 1386     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.459    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 451      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5695     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.429    |
# |    n_updates        | 1398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 451      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5738     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.398    |
# |    n_updates        | 1409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 451      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5778     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.594    |
# |    n_updates        | 1419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 452      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5821     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0628   |
# |    n_updates        | 1430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 452      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5881     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.475    |
# |    n_updates        | 1445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.436    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 452      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 5936     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.431    |
# |    n_updates        | 1458     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 452      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 6016     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0671   |
# |    n_updates        | 1478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 452      |
# ...
# |    n_updates        | 22079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 431      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 89117    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0562   |
# |    n_updates        | 22254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 431      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 89850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00109  |
# |    n_updates        | 22437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 431      |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 90638    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0485   |
# |    n_updates        | 22634    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 431      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 91361    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00293  |
# |    n_updates        | 22815    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 431      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 92115    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 23003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 431      |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 92831    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0557   |
# |    n_updates        | 23182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 432      |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 93687    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0476   |
# |    n_updates        | 23396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 432      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 94610    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 23627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 432      |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 95346    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00933  |
# |    n_updates        | 23811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 431      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 96019    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00623  |
# |    n_updates        | 23979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 432      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 96700    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0502   |
# |    n_updates        | 24149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 432      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 97400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00287  |
# |    n_updates        | 24324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 432      |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 98078    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00184  |
# |    n_updates        | 24494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 432      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 98734    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00479  |
# |    n_updates        | 24658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 432      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 99376    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 24818    |
# ----------------------------------
# Reward in episode: 176.59 +/- 20.31
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img46a787ad876a430a8e6e87baa4c79799">
#   <div class="anim-controls">
#     <input id="_anim_slider46a787ad876a430a8e6e87baa4c79799" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim46a787ad876a430a8e6e87baa4c79799.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim46a787ad876a430a8e6e87baa4c79799.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim46a787ad876a430a8e6e87baa4c79799.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim46a787ad876a430a8e6e87baa4c79799.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim46a787ad876a430a8e6e87baa4c79799.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim46a787ad876a430a8e6e87baa4c79799.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim46a787ad876a430a8e6e87baa4c79799.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim46a787ad876a430a8e6e87baa4c79799.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim46a787ad876a430a8e6e87baa4c79799.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim46a787ad876a430a8e6e87baa4c79799.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select46a787ad876a430a8e6e87baa4c79799"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_46a787ad876a430a8e6e87baa4c79799"
#              >
#       <label for="_anim_radio1_46a787ad876a430a8e6e87baa4c79799">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_46a787ad876a430a8e6e87baa4c79799"
#              checked>
#       <label for="_anim_radio2_46a787ad876a430a8e6e87baa4c79799">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_46a787ad876a430a8e6e87baa4c79799"
#              >
#       <label for="_anim_radio3_46a787ad876a430a8e6e87baa4c79799">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img46a787ad876a430a8e6e87baa4c79799";
#     var slider_id = "_anim_slider46a787ad876a430a8e6e87baa4c79799";
#     var loop_select_id = "_anim_loop_select46a787ad876a430a8e6e87baa4c79799";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjksIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvJkbTWQAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAALC9JR
# Max reward: 326.0

# %% [markdown]
# Jak widać rezultaty są dużo lepsze. Ale może udałoby się poprawić proces trenowania? Tego dotyczyć będą zadania.

# %% [markdown]
# ## Zadanie 1
#
# Zbadaj wpływ pozostałych ze wspomnianych hipeparametrów na trenowanie i działanie modelu. Skup się na zmianie architektury modelu strategii, hiperparametrach trenowania (gamma, epsilon itp.). Zapisz swoje wnioski oraz przygotuj wizualizacje uzyskiwanych rezultatów oraz animacje działania modelu.

# %%
def train_and_evaluate_dqn(env_name="CartPole-v1", log_base_dir="/tmp/dqn_tests/", **kwargs):
    experiment_name = kwargs.pop("experiment_name", "Test")
    log_dir = os.path.join(log_base_dir, experiment_name)
    os.makedirs(log_dir, exist_ok=True)

    env = gym.make(env_name)
    env = Monitor(env, filename=log_dir)

    params = {
        "learning_rate": 1e-3,
        "batch_size": 64,
        "gamma": 0.99,
        "target_update_interval": 500,
        "exploration_initial_eps": 1.0,
        "exploration_final_eps": 0.05,
        "exploration_fraction": 0.5,
        "policy_kwargs": {"net_arch": [128, 128]},
        "seed": 13,
        "verbose": 0
    }
    params.update(kwargs)
    model = DQN("MlpPolicy", env, **params)

    total_timesteps = 50000
    print(f"Trenowanie eksperymentu: {experiment_name}...")
    model.learn(total_timesteps=total_timesteps)

    results = load_results(log_dir)
    max_reward = results.r.max()
    print(f"Maksymalna nagroda ({experiment_name}): {max_reward}")

    plot_results([log_dir], total_timesteps, "timesteps", f"Wyniki: {experiment_name}")
    plt.show()

    return model

model_arch_small = train_and_evaluate_dqn(experiment_name="Arch_Small_32", policy_kwargs={"net_arch": [32]})
model_arch_large = train_and_evaluate_dqn(experiment_name="Arch_Large_256_256", policy_kwargs={"net_arch": [256, 256]})

model_gamma_low = train_and_evaluate_dqn(experiment_name="Gamma_0.5", gamma=0.5)
model_gamma_high = train_and_evaluate_dqn(experiment_name="Gamma_0.99", gamma=0.99)

model_eps_fast = train_and_evaluate_dqn(experiment_name="Eps_Fast_0.1", exploration_fraction=0.1)
model_eps_slow = train_and_evaluate_dqn(experiment_name="Eps_Slow_0.9", exploration_fraction=0.9)
# Out:
# Trenowanie eksperymentu: Arch_Small_32...
# Maksymalna nagroda (Arch_Small_32): 220.0
# Trenowanie eksperymentu: Arch_Large_256_256...
# Maksymalna nagroda (Arch_Large_256_256): 278.0
# Trenowanie eksperymentu: Gamma_0.5...
# Maksymalna nagroda (Gamma_0.5): 500.0
# Trenowanie eksperymentu: Gamma_0.99...
# Maksymalna nagroda (Gamma_0.99): 500.0
# Trenowanie eksperymentu: Eps_Fast_0.1...
# Maksymalna nagroda (Eps_Fast_0.1): 485.0
# Trenowanie eksperymentu: Eps_Slow_0.9...
# Maksymalna nagroda (Eps_Slow_0.9): 240.0

# %% [markdown]
# ## Zadanie 2
#
# Wykorzystaj metodę Deep Q-Learning do przygotowania agenta działającego w wybranym innym środowisku z biblioteki [Gymnasium](https://gymnasium.farama.org/index.html). Ze względu na cechy modelu zwróć uwagę na dopasowanie środowiska (np. przestrzeń akcji powinna być dyskretna). Zapoznaj się z definicją funkcji nagrody przyznawanej agentowi w środowisku, aby można było zinterpretować rezultaty osiągane przez model. Jeśli zdecydujesz się na wykorzystanie środowiska z obserwacjami wizualnymi, pamiętaj o zmianie typu modelu strategii (uwaga: trenowanie modeli w oparciu o obserwacje wizualne z wykorzystaniem sieci konwolucyjnym jest długotrwałe i może być bardziej niestabilne niż w przypadku strategii MLP). Spróbuj dostroić hiperparametry trenowania do nowego środowiska.

# %%
env_id = "LunarLander-v3"
log_dir = "/tmp/lunar_lander_dqn_tuned/"
os.makedirs(log_dir, exist_ok=True)

env = gym.make(env_id, render_mode="rgb_array")
env = Monitor(env, filename=log_dir)

model = DQN(
    "MlpPolicy",
    env,
    learning_rate=0.00063,
    buffer_size=100000,
    learning_starts=10000,
    batch_size=128,
    gamma=0.99,
    target_update_interval=250,
    train_freq=4,
    gradient_steps=1,
    exploration_fraction=0.3,
    exploration_final_eps=0.05,
    policy_kwargs=dict(net_arch=[256, 256]),
    verbose=1,
    seed=13
)

total_timesteps = 300000
print("Rozpoczynam trenowanie lądownika.")
model.learn(total_timesteps=total_timesteps)
print("Trenowanie zakończone")

display(ipythondisplay.HTML(visualize_model(model, max_steps=1000)))
plot_results([log_dir], total_timesteps, "timesteps", "Zoptymalizowany LunarLander DQN")
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# Rozpoczynam trenowanie lądownika. Zwiększono liczbę kroków, więc potrwa to dłużej...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.8     |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2018     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 323      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2099     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 729      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2336     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1110     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2443     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2311     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1761     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -141     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2353     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2394     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2409     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2843     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2426     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2427     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2468     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2455     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2478     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2444     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2443     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2433     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2443     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2427     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2430     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2444     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2459     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2446     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2465     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2476     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2485     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2501     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2494     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2213     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10210    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.49     |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1867     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10609    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.62     |
# |    n_updates        | 152      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1624     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 11043    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.61     |
# |    n_updates        | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1458     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 11424    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.724    |
# |    n_updates        | 355      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1314     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 11876    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.01     |
# |    n_updates        | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1216     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 12247    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.81     |
# |    n_updates        | 561      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1142     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 12577    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.8      |
# |    n_updates        | 644      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1086     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 12910    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 3.68     |
# |    n_updates        | 727      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1017     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13382    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.26     |
# |    n_updates        | 845      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 958      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13829    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.968    |
# |    n_updates        | 957      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 921      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 14166    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.94     |
# |    n_updates        | 1041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 892      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14490    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 3.87     |
# |    n_updates        | 1122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 841      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 14965    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.912    |
# |    n_updates        | 1241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 815      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 15320    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.25     |
# |    n_updates        | 1329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 770      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 15767    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.49     |
# |    n_updates        | 1441     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 751      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 16145    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 4.85     |
# |    n_updates        | 1536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 738      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 16453    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.57     |
# |    n_updates        | 1613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -142     |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 721      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 16876    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.518    |
# |    n_updates        | 1718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 708      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 17205    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.1      |
# |    n_updates        | 1801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 695      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 17618    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.24     |
# |    n_updates        | 1904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 683      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 18025    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 3.13     |
# |    n_updates        | 2006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -121     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 670      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 18432    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 4.9      |
# |    n_updates        | 2107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 658      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18826    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.08     |
# |    n_updates        | 2206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 649      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19206    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.22     |
# |    n_updates        | 2301     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 640      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19617    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.89     |
# |    n_updates        | 2404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 632      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 19986    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.5      |
# |    n_updates        | 2496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.7     |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 623      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 20376    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.858    |
# |    n_updates        | 2593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.7     |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 616      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 20814    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.69     |
# |    n_updates        | 2703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | -100     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 609      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 21215    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.861    |
# |    n_updates        | 2803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98       |
# |    ep_rew_mean      | -99.9    |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 602      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 21679    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.03     |
# |    n_updates        | 2919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -99.4    |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 596      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 22073    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.64     |
# |    n_updates        | 3018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -98.8    |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 590      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 22479    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.462    |
# |    n_updates        | 3119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -96      |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 586      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 22808    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.16     |
# |    n_updates        | 3201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | -93.2    |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 580      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 23173    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1        |
# |    n_updates        | 3293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -91.6    |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 573      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 23642    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.78     |
# |    n_updates        | 3410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -90.9    |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 568      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 24059    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.18     |
# |    n_updates        | 3514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -88      |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 563      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 24447    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.15     |
# |    n_updates        | 3611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98       |
# |    ep_rew_mean      | -87.8    |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 559      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 24766    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.663    |
# |    n_updates        | 3691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | -86.2    |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 555      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 25113    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.31     |
# |    n_updates        | 3778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | -84.3    |
# |    exploration_rate | 0.731    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 551      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 25473    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.79     |
# |    n_updates        | 3868     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -83.4    |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 547      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 25885    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2        |
# |    n_updates        | 3971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -83.4    |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 543      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 26290    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.02     |
# |    n_updates        | 4072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | -84      |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 540      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 26632    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.993    |
# |    n_updates        | 4157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -84.8    |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 537      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 27091    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.77     |
# |    n_updates        | 4272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -83.6    |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 532      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 27588    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.09     |
# |    n_updates        | 4396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -83      |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 529      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 27970    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1        |
# |    n_updates        | 4492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -83.3    |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 526      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 28332    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.03     |
# |    n_updates        | 4582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -81      |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 522      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 28761    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.14     |
# |    n_updates        | 4690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.1     |
# |    ep_rew_mean      | -80.8    |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 520      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 29120    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.12     |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -81.8    |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 517      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 29521    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 3.22     |
# |    n_updates        | 4880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -79.4    |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 515      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 29874    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 3.45     |
# |    n_updates        | 4968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -80.3    |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 512      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 30248    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.702    |
# |    n_updates        | 5061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | -78.6    |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 509      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 30666    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.746    |
# |    n_updates        | 5166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | -77.7    |
# |    exploration_rate | 0.672    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 506      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 31070    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.88     |
# |    n_updates        | 5267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -75.9    |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 504      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 31432    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 4.62     |
# |    n_updates        | 5357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -75.4    |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 502      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 31814    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 6.6      |
# |    n_updates        | 5453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -75.3    |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 497      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 32487    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 3.47     |
# |    n_updates        | 5621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -73.5    |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 495      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 32875    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.95     |
# |    n_updates        | 5718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -72.7    |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 492      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 33284    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.18     |
# |    n_updates        | 5820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -71.3    |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 490      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 33681    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 14.2     |
# |    n_updates        | 5920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -70      |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 488      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 34093    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 5.97     |
# |    n_updates        | 6023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -69.7    |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 486      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 34454    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 12.4     |
# |    n_updates        | 6113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -69.9    |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 483      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 34881    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 3.91     |
# |    n_updates        | 6220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -70.6    |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 481      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 35250    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.96     |
# |    n_updates        | 6312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -69.2    |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 479      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 35727    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 4.25     |
# |    n_updates        | 6431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -68.4    |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 474      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 36229    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 9.87     |
# |    n_updates        | 6557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -68.4    |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 472      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 36591    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.11     |
# |    n_updates        | 6647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -66.4    |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 470      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 37003    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.45     |
# |    n_updates        | 6750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -62.8    |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 468      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 37471    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.79     |
# |    n_updates        | 6867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -61.7    |
# |    exploration_rate | 0.6      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 466      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 37868    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 8.33     |
# |    n_updates        | 6966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -60.7    |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 465      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 38201    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.66     |
# |    n_updates        | 7050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -58.6    |
# |    exploration_rate | 0.591    |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 340      |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 214      |
# |    time_elapsed     | 1317     |
# |    total_timesteps  | 282410   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.184    |
# |    n_updates        | 68102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 343      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 214      |
# |    time_elapsed     | 1324     |
# |    total_timesteps  | 283871   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.819    |
# |    n_updates        | 68467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 342      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 214      |
# |    time_elapsed     | 1328     |
# |    total_timesteps  | 284980   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.648    |
# |    n_updates        | 68744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 346      |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 214      |
# |    time_elapsed     | 1336     |
# |    total_timesteps  | 286655   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.26     |
# |    n_updates        | 69163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 342      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 214      |
# |    time_elapsed     | 1340     |
# |    total_timesteps  | 287600   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.486    |
# |    n_updates        | 69399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 344      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 214      |
# |    time_elapsed     | 1346     |
# |    total_timesteps  | 289019   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.832    |
# |    n_updates        | 69754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 341      |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 214      |
# |    time_elapsed     | 1350     |
# |    total_timesteps  | 290262   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.377    |
# |    n_updates        | 70065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 339      |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 214      |
# |    time_elapsed     | 1355     |
# |    total_timesteps  | 291481   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.808    |
# |    n_updates        | 70370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 334      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 214      |
# |    time_elapsed     | 1362     |
# |    total_timesteps  | 292791   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.12     |
# |    n_updates        | 70697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 340      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 214      |
# |    time_elapsed     | 1370     |
# |    total_timesteps  | 294289   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.128    |
# |    n_updates        | 71072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 342      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 214      |
# |    time_elapsed     | 1376     |
# |    total_timesteps  | 295497   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.173    |
# |    n_updates        | 71374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 340      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 214      |
# |    time_elapsed     | 1381     |
# |    total_timesteps  | 296442   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.492    |
# |    n_updates        | 71610    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 214      |
# |    time_elapsed     | 1384     |
# |    total_timesteps  | 297224   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.09     |
# |    n_updates        | 71805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 214      |
# |    time_elapsed     | 1387     |
# |    total_timesteps  | 298057   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.95     |
# |    n_updates        | 72014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 338      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 214      |
# |    time_elapsed     | 1391     |
# |    total_timesteps  | 299034   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.154    |
# |    n_updates        | 72258    |
# ----------------------------------
# Trenowanie zakończone
# Reward in episode: 261.41 +/- 48.36
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9b5160a2c78d42cda888bf9301be0d40">
#   <div class="anim-controls">
#     <input id="_anim_slider9b5160a2c78d42cda888bf9301be0d40" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9b5160a2c78d42cda888bf9301be0d40.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim9b5160a2c78d42cda888bf9301be0d40.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim9b5160a2c78d42cda888bf9301be0d40.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim9b5160a2c78d42cda888bf9301be0d40.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim9b5160a2c78d42cda888bf9301be0d40.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim9b5160a2c78d42cda888bf9301be0d40.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim9b5160a2c78d42cda888bf9301be0d40.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim9b5160a2c78d42cda888bf9301be0d40.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim9b5160a2c78d42cda888bf9301be0d40.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim9b5160a2c78d42cda888bf9301be0d40.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select9b5160a2c78d42cda888bf9301be0d40"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9b5160a2c78d42cda888bf9301be0d40"
#              >
#       <label for="_anim_radio1_9b5160a2c78d42cda888bf9301be0d40">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9b5160a2c78d42cda888bf9301be0d40"
#              checked>
#       <label for="_anim_radio2_9b5160a2c78d42cda888bf9301be0d40">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9b5160a2c78d42cda888bf9301be0d40"
#              >
#       <label for="_anim_radio3_9b5160a2c78d42cda888bf9301be0d40">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9b5160a2c78d42cda888bf9301be0d40";
#     var slider_id = "_anim_slider9b5160a2c78d42cda888bf9301be0d40";
#     var loop_select_id = "_anim_loop_select9b5160a2c78d42cda888bf9301be0d40";
#     var frames = new Array(232);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjksIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvJkbTWQAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAN0JJ
